# %%
import numpy as np
import pandas as pd
import os 
import time
import deepdish.io as dd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

import torch
import torch.nn as nn
import torchvision
import torch.nn.functional as F

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler, StandardScaler

from svi import SVI
import models as m
import datasets as d

# %% [markdown]
# # Load and Prepare Data

# %%
data = dd.load("sequenced_data_for_VAE_lenght-160_stride-10.h5")

# %%
X,y = data["X"], data["y"]

# %%
X.shape
# Out:
# torch.Size([83680, 160])

# %%
X_train, X_test, y_train, y_test = train_test_split(np.array(X), np.array(y), test_size=0.2, random_state=666)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
train = d.H_alphaSequences(X_train, y_train)
test = d.H_alphaSequences(X_test, y_test)

# %%
train_loader = torch.utils.data.DataLoader(dataset = train, batch_size=100, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset = test, batch_size=100, shuffle=True)

# %% [markdown]
# # Model setup

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.get_device_name()
# Out:
# 'GeForce GTX 1070'

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
model_name = "DeepConvVAE_ReLU_NLL_200ep_lr-1e-4_bs-100"

# %%
deepmodel = m.DeepConvVAE(original_dim=160, latent_dim=15) #m.DeepConvVAE_ReLU(original_dim=160, latent_dim=15)
svi = SVI(
        vae_model=deepmodel,
        optimizer=torch.optim.Adam(deepmodel.parameters(), lr=1e-4),
        loss_function="GaussianNLL",
        verbose=True
        )
# Out:
# cuda:0

# %%
loss_hist = svi(epochs=100, train_loader=train_loader, validation_loader=test_loader, flatten=False)
# Out:
# Epoch [1/100], average_loss:134.4468, validation_loss:30.0839
# Epoch [2/100], average_loss:-13.8619, validation_loss:-43.6361
# Epoch [3/100], average_loss:-59.3204, validation_loss:-75.3418
# Epoch [4/100], average_loss:-80.7359, validation_loss:-91.6936
# Epoch [5/100], average_loss:-94.9052, validation_loss:-101.3698
# Epoch [6/100], average_loss:-105.5147, validation_loss:-110.5254
# Epoch [7/100], average_loss:-113.3320, validation_loss:-113.8182
# Epoch [8/100], average_loss:-118.8503, validation_loss:-121.7843
# Epoch [9/100], average_loss:-124.1301, validation_loss:-123.2557
# Epoch [10/100], average_loss:-128.2665, validation_loss:-129.8772
# Epoch [11/100], average_loss:-132.1490, validation_loss:-132.6249
# Epoch [12/100], average_loss:-134.8537, validation_loss:-133.4312
# Epoch [13/100], average_loss:-137.8904, validation_loss:-137.9273
# Epoch [14/100], average_loss:-140.1807, validation_loss:-140.6268
# Epoch [15/100], average_loss:-142.9277, validation_loss:-142.7932
# Epoch [16/100], average_loss:-144.6302, validation_loss:-144.3935
# Epoch [17/100], average_loss:-146.4213, validation_loss:-145.3461
# Epoch [18/100], average_loss:-148.6738, validation_loss:-147.8751
# Epoch [19/100], average_loss:-149.7017, validation_loss:-144.4464
# Epoch [20/100], average_loss:-151.6598, validation_loss:-150.5098
# Epoch [21/100], average_loss:-152.6846, validation_loss:-152.0306
# Epoch [22/100], average_loss:-153.7847, validation_loss:-153.5575
# Epoch [23/100], average_loss:-155.1006, validation_loss:-153.5912
# Epoch [24/100], average_loss:-156.1320, validation_loss:-154.3891
# Epoch [25/100], average_loss:-156.7759, validation_loss:-155.6038
# Epoch [26/100], average_loss:-158.4066, validation_loss:-157.4448
# Epoch [27/100], average_loss:-158.4171, validation_loss:-156.0556
# Epoch [28/100], average_loss:-159.5817, validation_loss:-158.5313
# Epoch [29/100], average_loss:-159.9025, validation_loss:-156.9578
# Epoch [30/100], average_loss:-160.2714, validation_loss:-158.7863
# Epoch [31/100], average_loss:-161.4226, validation_loss:-159.7688
# Epoch [32/100], average_loss:-161.9951, validation_loss:-160.0853
# Epoch [33/100], average_loss:-162.1817, validation_loss:-159.0500
# Epoch [34/100], average_loss:-162.9730, validation_loss:-160.8894
# Epoch [35/100], average_loss:-163.4011, validation_loss:-161.3352
# Epoch [36/100], average_loss:-163.5050, validation_loss:-155.8716
# Epoch [37/100], average_loss:-164.2062, validation_loss:-163.4106
# Epoch [38/100], average_loss:-164.8734, validation_loss:-161.9896
# Epoch [39/100], average_loss:-165.2394, validation_loss:-164.2181
# Epoch [40/100], average_loss:-165.3023, validation_loss:-161.0276
# Epoch [41/100], average_loss:-165.9398, validation_loss:-164.6856
# Epoch [42/100], average_loss:-166.1009, validation_loss:-164.3524
# Epoch [43/100], average_loss:-166.5970, validation_loss:-164.9784
# Epoch [44/100], average_loss:-166.6392, validation_loss:-165.2870
# Epoch [45/100], average_loss:-167.3133, validation_loss:-165.3911
# Epoch [46/100], average_loss:-167.6811, validation_loss:-163.9821
# Epoch [47/100], average_loss:-167.9909, validation_loss:-166.2808
# Epoch [48/100], average_loss:-167.9493, validation_loss:-160.2577
# Epoch [49/100], average_loss:-168.3989, validation_loss:-166.9537
# Epoch [50/100], average_loss:-168.5389, validation_loss:-167.3478
# Epoch [51/100], average_loss:-168.9855, validation_loss:-166.0800
# Epoch [52/100], average_loss:-169.3630, validation_loss:-165.1930
# Epoch [53/100], average_loss:-169.3985, validation_loss:-168.6037
# Epoch [54/100], average_loss:-169.7868, validation_loss:-167.0698
# Epoch [55/100], average_loss:-170.0536, validation_loss:-167.3605
# Epoch [56/100], average_loss:-169.9160, validation_loss:-168.1358
# Epoch [57/100], average_loss:-170.4364, validation_loss:-164.3263
# Epoch [58/100], average_loss:-170.5852, validation_loss:-166.1585
# Epoch [59/100], average_loss:-170.8634, validation_loss:-169.2056
# Epoch [60/100], average_loss:-171.3090, validation_loss:-169.9832
# Epoch [61/100], average_loss:-171.4237, validation_loss:-169.6841
# Epoch [62/100], average_loss:-171.7621, validation_loss:-170.4489
# Epoch [63/100], average_loss:-171.4106, validation_loss:-169.2674
# Epoch [64/100], average_loss:-172.2021, validation_loss:-168.9969
# Epoch [65/100], average_loss:-172.1703, validation_loss:-170.2833
# Epoch [66/100], average_loss:-172.1843, validation_loss:-170.2117
# Epoch [67/100], average_loss:-172.5401, validation_loss:-168.6190
# Epoch [68/100], average_loss:-172.6423, validation_loss:-170.8512
# Epoch [69/100], average_loss:-172.8539, validation_loss:-171.7226
# Epoch [70/100], average_loss:-173.0890, validation_loss:-171.3402
# Epoch [71/100], average_loss:-173.3381, validation_loss:-171.9413
# Epoch [72/100], average_loss:-173.7348, validation_loss:-172.0529
# Epoch [73/100], average_loss:-173.1105, validation_loss:-171.6678
# Epoch [74/100], average_loss:-173.9207, validation_loss:-169.8927
# Epoch [75/100], average_loss:-173.8881, validation_loss:-172.7785
# Epoch [76/100], average_loss:-174.1523, validation_loss:-172.4577
# Epoch [77/100], average_loss:-174.4747, validation_loss:-173.0165
# Epoch [78/100], average_loss:-174.4355, validation_loss:-172.9652
# Epoch [79/100], average_loss:-174.6362, validation_loss:-173.1787
# Epoch [80/100], average_loss:-174.5034, validation_loss:-173.5292
# Epoch [81/100], average_loss:-175.2534, validation_loss:-171.0065
# Epoch [82/100], average_loss:-175.0861, validation_loss:-170.0532
# Epoch [83/100], average_loss:-175.2590, validation_loss:-173.2760
# Epoch [84/100], average_loss:-175.7118, validation_loss:-173.4383
# Epoch [85/100], average_loss:-175.7011, validation_loss:-173.5906
# Epoch [86/100], average_loss:-176.0387, validation_loss:-173.6803
# Epoch [87/100], average_loss:-176.2360, validation_loss:-174.4043
# Epoch [88/100], average_loss:-176.7674, validation_loss:-175.2275
# Epoch [89/100], average_loss:-177.1652, validation_loss:-175.4736
# Epoch [90/100], average_loss:-177.5208, validation_loss:-175.6622
# Epoch [91/100], average_loss:-177.9395, validation_loss:-173.5257
# Epoch [92/100], average_loss:-178.8112, validation_loss:-172.7577
# Epoch [93/100], average_loss:-179.7185, validation_loss:-178.1044
# Epoch [94/100], average_loss:-181.3848, validation_loss:-179.4213
# Epoch [95/100], average_loss:-183.2923, validation_loss:-181.8892
# Epoch [96/100], average_loss:-185.2475, validation_loss:-183.6560
# Epoch [97/100], average_loss:-187.0368, validation_loss:-186.3845
# Epoch [98/100], average_loss:-189.4731, validation_loss:-188.7294
# Epoch [99/100], average_loss:-191.6733, validation_loss:-189.9633
# Epoch [100/100], average_loss:-193.8161, validation_loss:-193.1997

# %%
loss_hist = svi(epochs=50, train_loader=train_loader, validation_loader=test_loader, flatten=False)
# Out:
# Epoch [1/50], average_loss:-196.0962, validation_loss:-195.2530
# Epoch [2/50], average_loss:-197.6309, validation_loss:-194.9531
# Epoch [3/50], average_loss:-198.9121, validation_loss:-197.5834
# Epoch [4/50], average_loss:-199.7636, validation_loss:-198.5232
# Epoch [5/50], average_loss:-200.7699, validation_loss:-199.3104
# Epoch [6/50], average_loss:-201.7861, validation_loss:-200.5380
# Epoch [7/50], average_loss:-202.1083, validation_loss:-199.5701
# Epoch [8/50], average_loss:-202.5029, validation_loss:-201.3628
# Epoch [9/50], average_loss:-203.0199, validation_loss:-201.4152
# Epoch [10/50], average_loss:-203.8468, validation_loss:-201.6206
# Epoch [11/50], average_loss:-203.9911, validation_loss:-200.6217
# Epoch [12/50], average_loss:-204.5162, validation_loss:-201.6577
# Epoch [13/50], average_loss:-204.5423, validation_loss:-202.8190
# Epoch [14/50], average_loss:-204.8292, validation_loss:-202.9223
# Epoch [15/50], average_loss:-205.4039, validation_loss:-202.7541
# Epoch [16/50], average_loss:-205.6277, validation_loss:-203.4749
# Epoch [17/50], average_loss:-205.7479, validation_loss:-204.0470
# Epoch [18/50], average_loss:-206.2641, validation_loss:-203.8458
# Epoch [19/50], average_loss:-206.0731, validation_loss:-203.1774
# Epoch [20/50], average_loss:-206.6414, validation_loss:-204.2817
# Epoch [21/50], average_loss:-206.7484, validation_loss:-203.5482
# Epoch [22/50], average_loss:-207.0965, validation_loss:-204.9249
# Epoch [23/50], average_loss:-207.2808, validation_loss:-204.7529
# Epoch [24/50], average_loss:-207.3786, validation_loss:-204.9436
# Epoch [25/50], average_loss:-207.5956, validation_loss:-204.8687
# Epoch [26/50], average_loss:-208.0866, validation_loss:-205.4196
# Epoch [27/50], average_loss:-207.7963, validation_loss:-204.9722
# Epoch [28/50], average_loss:-208.3295, validation_loss:-204.5687
# Epoch [29/50], average_loss:-208.3909, validation_loss:-206.0819
# Epoch [30/50], average_loss:-208.4913, validation_loss:-205.3399
# Epoch [31/50], average_loss:-208.5748, validation_loss:-206.5689
# Epoch [32/50], average_loss:-208.7601, validation_loss:-205.6193
# Epoch [33/50], average_loss:-208.9411, validation_loss:-206.7236
# Epoch [34/50], average_loss:-209.2194, validation_loss:-206.5033
# Epoch [35/50], average_loss:-209.5215, validation_loss:-205.5765
# Epoch [36/50], average_loss:-209.4234, validation_loss:-206.7687
# Epoch [37/50], average_loss:-209.6430, validation_loss:-207.3631
# Epoch [38/50], average_loss:-209.7939, validation_loss:-206.9579
# Epoch [39/50], average_loss:-209.5803, validation_loss:-207.6804
# Epoch [40/50], average_loss:-210.2768, validation_loss:-208.2328
# Epoch [41/50], average_loss:-210.0416, validation_loss:-206.4982
# Epoch [42/50], average_loss:-210.2715, validation_loss:-207.4442
# Epoch [43/50], average_loss:-210.2487, validation_loss:-206.5439
# Epoch [44/50], average_loss:-210.5113, validation_loss:-206.5992
# Epoch [45/50], average_loss:-210.6067, validation_loss:-208.3269
# Epoch [46/50], average_loss:-210.5489, validation_loss:-208.0985
# Epoch [47/50], average_loss:-210.9844, validation_loss:-208.5971
# Epoch [48/50], average_loss:-211.0950, validation_loss:-208.5432
# Epoch [49/50], average_loss:-211.1650, validation_loss:-208.9644
# Epoch [50/50], average_loss:-211.3068, validation_loss:-207.3582

# %%
loss_hist = svi(epochs=50, train_loader=train_loader, validation_loader=test_loader, flatten=False)
# Out:
# Epoch [1/50], average_loss:-211.4223, validation_loss:-207.9592
# Epoch [2/50], average_loss:-211.4727, validation_loss:-205.7724
# Epoch [3/50], average_loss:-211.5489, validation_loss:-208.8793
# Epoch [4/50], average_loss:-211.6744, validation_loss:-209.0354
# Epoch [5/50], average_loss:-211.3134, validation_loss:-209.5204
# Epoch [6/50], average_loss:-212.0183, validation_loss:-209.0745
# Epoch [7/50], average_loss:-212.1357, validation_loss:-209.9420
# Epoch [8/50], average_loss:-212.0698, validation_loss:-198.6701
# Epoch [9/50], average_loss:-212.3225, validation_loss:-209.9132
# Epoch [10/50], average_loss:-212.2016, validation_loss:-210.1527
# Epoch [11/50], average_loss:-212.4911, validation_loss:-210.0374
# Epoch [12/50], average_loss:-212.0466, validation_loss:-207.1752
# Epoch [13/50], average_loss:-212.5539, validation_loss:-207.3566
# Epoch [14/50], average_loss:-212.9228, validation_loss:-210.3038
# Epoch [15/50], average_loss:-212.8459, validation_loss:-209.6984
# Epoch [16/50], average_loss:-212.7170, validation_loss:-209.6908
# Epoch [17/50], average_loss:-213.1698, validation_loss:-209.8930
# Epoch [18/50], average_loss:-213.0869, validation_loss:-209.3377
# Epoch [19/50], average_loss:-212.9996, validation_loss:-211.3750
# Epoch [20/50], average_loss:-213.3201, validation_loss:-210.5901
# Epoch [21/50], average_loss:-213.3955, validation_loss:-210.6733
# Epoch [22/50], average_loss:-213.2883, validation_loss:-210.5899
# Epoch [23/50], average_loss:-213.5278, validation_loss:-208.7683
# Epoch [24/50], average_loss:-213.5212, validation_loss:-210.7552
# Epoch [25/50], average_loss:-213.6053, validation_loss:-210.7110
# Epoch [26/50], average_loss:-213.7738, validation_loss:-210.8668
# Epoch [27/50], average_loss:-213.8223, validation_loss:-210.0425
# Epoch [28/50], average_loss:-213.9178, validation_loss:-211.7353
# Epoch [29/50], average_loss:-214.0203, validation_loss:-210.7372
# Epoch [30/50], average_loss:-213.9828, validation_loss:-211.1910
# Epoch [31/50], average_loss:-214.3400, validation_loss:-210.8939
# Epoch [32/50], average_loss:-214.2316, validation_loss:-211.2694
# Epoch [33/50], average_loss:-214.3035, validation_loss:-212.1758
# Epoch [34/50], average_loss:-214.3814, validation_loss:-211.4989
# Epoch [35/50], average_loss:-214.5005, validation_loss:-211.9231
# Epoch [36/50], average_loss:-214.5789, validation_loss:-211.8681
# Epoch [37/50], average_loss:-214.6131, validation_loss:-211.3758
# Epoch [38/50], average_loss:-214.5251, validation_loss:-211.6020
# Epoch [39/50], average_loss:-214.9036, validation_loss:-211.9680
# Epoch [40/50], average_loss:-214.7741, validation_loss:-210.5382
# Epoch [41/50], average_loss:-214.9529, validation_loss:-212.8830
# Epoch [42/50], average_loss:-215.0544, validation_loss:-211.7007
# Epoch [43/50], average_loss:-214.9564, validation_loss:-212.0250
# Epoch [44/50], average_loss:-215.1347, validation_loss:-213.0745
# Epoch [45/50], average_loss:-215.2329, validation_loss:-212.4918
# Epoch [46/50], average_loss:-215.0139, validation_loss:-211.4291
# Epoch [47/50], average_loss:-215.2552, validation_loss:-212.9891
# Epoch [48/50], average_loss:-215.5958, validation_loss:-212.2554
# Epoch [49/50], average_loss:-215.5028, validation_loss:-211.2267
# Epoch [50/50], average_loss:-215.5367, validation_loss:-213.0695

# %%
plt.figure(figsize=(15,8))
plt.title("train and validation loss")
epoch_axis = np.arange(len(svi.loss_history["train"]))
plt.plot(epoch_axis, np.array(svi.loss_history["train"]), lw=0.5) #np.arange(len(svi.loss_history["validation"]))*10
plt.plot(np.arange(len(svi.loss_history["validation"]))*10, svi.loss_history["validation"])
plt.grid(True)
plt.xlabel("epochs")
plt.ylabel("loss")
plt.show()

# %%
torch.save(svi.model, f"VAE_saves_and_logs/{model_name}.pt")
torch.save(svi.optimizer, f"VAE_saves_and_logs/{model_name}_optimizer.pt")
dd.save(f"VAE_saves_and_logs/{model_name}_loss_history.h5", svi.loss_history)

# %% [markdown]
# # Evaluation

# %%
#epoch 150
print(device)
X,_ = next(iter(test_loader))
output, mu, sigma = svi.model(X.to(device))
#X_hat = output.cpu().detach().numpy()
mu_hat = output[0].cpu().detach().numpy()
sigma = output[1].cpu().detach().numpy()

fig, axes = plt.subplots(10, 2, figsize=(15,50))
fig.tight_layout()
for i in range(10):
    axes[i][0].plot(X[i])
    axes[i][0].set_title('Original image')
    #axes[i][1].plot(X_hat[i])
    axes[i][1].plot(mu_hat[i])
    axes[i][1].fill_between(np.arange(160), mu_hat[i] + 2 * sigma[i], mu_hat[i] - 2 * sigma[i], alpha = 0.5, label="Uncertainty")
    axes[i][1].set_title('Reconstructed image')
# Out:
# cuda:0

# %%
#epoch 200
print(device)
X,_ = next(iter(test_loader))
output, mu, sigma = svi.model(X.to(device))
#X_hat = output.cpu().detach().numpy()
mu_hat = output[0].cpu().detach().numpy()
sigma = output[1].cpu().detach().numpy()

fig, axes = plt.subplots(10, 2, figsize=(15,50))
fig.tight_layout()
for i in range(10):
    axes[i][0].plot(X[i])
    axes[i][0].set_title('Original image')
    #axes[i][1].plot(X_hat[i])
    axes[i][1].plot(mu_hat[i])
    axes[i][1].fill_between(np.arange(160), mu_hat[i] + 2 * sigma[i], mu_hat[i] - 2 * sigma[i], alpha = 0.5, label="Uncertainty")
    axes[i][1].set_title('Reconstructed image')
# Out:
# cuda:0

# %% [markdown]
# # Load Model

# %%
mod = torch.load(f"VAE_saves_and_logs/{model_name}.pt")

# %%
mod.eval()
# Out:
# DeepConvVAE(
#   (encoder): Sequential(
#     (0): Reshape()
#     (1): Conv1d(1, 16, kernel_size=(6,), stride=(2,))
#     (2): ReLU()
#     (3): Conv1d(16, 32, kernel_size=(4,), stride=(2,))
#     (4): ReLU()
#     (5): Conv1d(32, 64, kernel_size=(4,), stride=(2,))
#     (6): ReLU()
#     (7): Flatten()
#     (8): VariationalLayer(
#       (mu): Linear(in_features=1152, out_features=15, bias=True)
#       (rho): Linear(in_features=1152, out_features=15, bias=True)
#       (softplus): Softplus(beta=1, threshold=20)
#     )
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=15, out_features=1152, bias=True)
#     (1): ReLU()
#     (2): Reshape()
#     (3): ConvTranspose1d(64, 32, kernel_size=(4,), stride=(2,))
#     (4): ReLU()
#     (5): ConvTranspose1d(32, 16, kernel_size=(4,), stride=(2,))
#     (6): ReLU()
#     (7): ConvTransposeDecoderOutput(
#       (mu): ConvTranspose1d(16, 1, kernel_size=(6,), stride=(2,))
#       (rho): Linear(in_features=1248, out_features=1, bias=True)
#       (flatten): Flatten()
#       (flatten_mu): Flatten()
#       (softplus): Softplus(beta=1, threshold=20)
#     )
#   )
# )

# %%
z, mu, sigma = mod.encoder(X.to(device))

# %%
# epoch 200
X_1, cl = test.X, test.y
Z_hat, mu, sigma = mod.encoder(X_1.to(device)) #.view(-1,28*28)
Z_hat = Z_hat.cpu().detach().numpy()
mu = mu.cpu().detach().numpy()

fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(111, projection='3d')
#ax.scatter(Z_hat[:,0], Z_hat[:,1], Z_hat[:,2], c=cl, lw=3)
sc = ax.scatter(mu[:,0], mu[:,1], mu[:,2], c=cl, lw=3)

# %%
# epoch 150
X_1, cl = test.X, test.y
Z_hat, mu, sigma = mod.encoder(X_1.to(device)) #.view(-1,28*28)
Z_hat = Z_hat.cpu().detach().numpy()
mu = mu.cpu().detach().numpy()

fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(111, projection='3d')
#ax.scatter(Z_hat[:,0], Z_hat[:,1], Z_hat[:,2], c=cl, lw=3)
sc = ax.scatter(mu[:,0], mu[:,1], mu[:,2], c=cl, lw=3)

# %%
# epoch 100
X_1, cl = test.X, test.y
Z_hat, mu, sigma = mod.encoder(X_1.to(device)) #.view(-1,28*28)
Z_hat = Z_hat.cpu().detach().numpy()
mu = mu.cpu().detach().numpy()

fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(111, projection='3d')
#ax.scatter(Z_hat[:,0], Z_hat[:,1], Z_hat[:,2], c=cl, lw=3)
sc = ax.scatter(mu[:,0], mu[:,1], mu[:,2], c=cl, lw=3)

# %%
# když přidám colorbar k obrázku tak se nehezky deformuje, tak je tady zvlášť
plt.colorbar(sc, shrink=1)

# %%
test.y
# Out:
# tensor([1., 1., 1.,  ..., 3., 1., 0.])
