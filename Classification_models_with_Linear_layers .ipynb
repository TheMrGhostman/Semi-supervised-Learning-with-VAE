# %%
import numpy as np 
import time
import os

import torch 
import torch.nn as nn
import torch.nn.functional as F 

import matplotlib.pyplot as plt
from collections import OrderedDict

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler, StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score

# %%
from utils.inference import Trainer, plot_loss
from utils.models import DNN
import utils.datasets as d

# %%
X = np.vstack((np.load("data/sequenced_data_for_VAE_length-160_stride-10_pt1.npy"),
               np.load("data/sequenced_data_for_VAE_length-160_stride-10_pt2.npy")))
y = np.load("data/sequenced_data_for_VAE_length-160_stride-10_targets.npy")

# %%
print(X.shape, y.shape)
# Out:
# (83680, 160) (83680,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=666)

# %%
scaler = RobustScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
train = d.H_alphaSequences(X_train, y_train)
test = d.H_alphaSequences(X_test, y_test)

# %% [markdown]
# # Hyperparameters search
# ## Batch size 100 + learning rate 1e-3 + Sigmoid

# %%
train_loader = torch.utils.data.DataLoader(dataset = train, batch_size=100, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset = test, batch_size=100, shuffle=True)

# %%
model1 = DNN(n_layers=2, neurons=[160, 128, 64], output_dim=4, activation=nn.Sigmoid(), dropout=False)

# %%
m1 = Trainer(
        model=model1,
        optimizer=torch.optim.Adam(model1.parameters(), lr=1e-3),
        loss_function=nn.CrossEntropyLoss(),
        verbose=True
        )
# Out:
# cuda:0

# %%
lh = m1(epochs=200, train_loader=train_loader, validation_loader=test_loader)
# Out:
# Epoch [1/200], average_loss:0.7270, validation_loss:0.5690
# Epoch [2/200], average_loss:0.5491, validation_loss:0.5229
# Epoch [3/200], average_loss:0.5216, validation_loss:0.5058
# Epoch [4/200], average_loss:0.5050, validation_loss:0.4927
# Epoch [5/200], average_loss:0.4914, validation_loss:0.4741
# Epoch [6/200], average_loss:0.4805, validation_loss:0.4631
# Epoch [7/200], average_loss:0.4718, validation_loss:0.4651
# Epoch [8/200], average_loss:0.4661, validation_loss:0.4566
# Epoch [9/200], average_loss:0.4592, validation_loss:0.4480
# Epoch [10/200], average_loss:0.4548, validation_loss:0.4404
# Epoch [11/200], average_loss:0.4500, validation_loss:0.4397
# Epoch [12/200], average_loss:0.4471, validation_loss:0.4392
# Epoch [13/200], average_loss:0.4450, validation_loss:0.4456
# Epoch [14/200], average_loss:0.4400, validation_loss:0.4431
# Epoch [15/200], average_loss:0.4372, validation_loss:0.4255
# Epoch [16/200], average_loss:0.4344, validation_loss:0.4252
# Epoch [17/200], average_loss:0.4309, validation_loss:0.4165
# Epoch [18/200], average_loss:0.4271, validation_loss:0.4146
# Epoch [19/200], average_loss:0.4223, validation_loss:0.4093
# Epoch [20/200], average_loss:0.4229, validation_loss:0.4083
# Epoch [21/200], average_loss:0.4191, validation_loss:0.4058
# Epoch [22/200], average_loss:0.4164, validation_loss:0.4058
# Epoch [23/200], average_loss:0.4146, validation_loss:0.3995
# Epoch [24/200], average_loss:0.4133, validation_loss:0.4162
# Epoch [25/200], average_loss:0.4107, validation_loss:0.4010
# Epoch [26/200], average_loss:0.4077, validation_loss:0.4058
# Epoch [27/200], average_loss:0.4067, validation_loss:0.3944
# Epoch [28/200], average_loss:0.4053, validation_loss:0.3983
# Epoch [29/200], average_loss:0.4040, validation_loss:0.3954
# Epoch [30/200], average_loss:0.4015, validation_loss:0.3946
# Epoch [31/200], average_loss:0.4002, validation_loss:0.3951
# Epoch [32/200], average_loss:0.3994, validation_loss:0.3881
# Epoch [33/200], average_loss:0.3970, validation_loss:0.3858
# Epoch [34/200], average_loss:0.3965, validation_loss:0.3840
# Epoch [35/200], average_loss:0.3944, validation_loss:0.3829
# Epoch [36/200], average_loss:0.3934, validation_loss:0.3810
# Epoch [37/200], average_loss:0.3916, validation_loss:0.3866
# Epoch [38/200], average_loss:0.3908, validation_loss:0.3799
# Epoch [39/200], average_loss:0.3895, validation_loss:0.3822
# Epoch [40/200], average_loss:0.3887, validation_loss:0.3792
# Epoch [41/200], average_loss:0.3874, validation_loss:0.3837
# Epoch [42/200], average_loss:0.3865, validation_loss:0.3850
# Epoch [43/200], average_loss:0.3851, validation_loss:0.3814
# Epoch [44/200], average_loss:0.3849, validation_loss:0.3794
# Epoch [45/200], average_loss:0.3829, validation_loss:0.3822
# Epoch [46/200], average_loss:0.3828, validation_loss:0.3753
# Epoch [47/200], average_loss:0.3823, validation_loss:0.3759
# Epoch [48/200], average_loss:0.3801, validation_loss:0.3815
# Epoch [49/200], average_loss:0.3795, validation_loss:0.3715
# Epoch [50/200], average_loss:0.3785, validation_loss:0.3704
# Epoch [51/200], average_loss:0.3763, validation_loss:0.3688
# Epoch [52/200], average_loss:0.3753, validation_loss:0.3692
# Epoch [53/200], average_loss:0.3758, validation_loss:0.3734
# Epoch [54/200], average_loss:0.3744, validation_loss:0.3702
# Epoch [55/200], average_loss:0.3723, validation_loss:0.3687
# Epoch [56/200], average_loss:0.3723, validation_loss:0.3643
# Epoch [57/200], average_loss:0.3707, validation_loss:0.3661
# Epoch [58/200], average_loss:0.3701, validation_loss:0.3682
# Epoch [59/200], average_loss:0.3685, validation_loss:0.3604
# Epoch [60/200], average_loss:0.3685, validation_loss:0.3641
# Epoch [61/200], average_loss:0.3665, validation_loss:0.3643
# Epoch [62/200], average_loss:0.3666, validation_loss:0.3698
# Epoch [63/200], average_loss:0.3657, validation_loss:0.3617
# Epoch [64/200], average_loss:0.3653, validation_loss:0.3605
# Epoch [65/200], average_loss:0.3649, validation_loss:0.3635
# Epoch [66/200], average_loss:0.3635, validation_loss:0.3606
# Epoch [67/200], average_loss:0.3625, validation_loss:0.3613
# Epoch [68/200], average_loss:0.3620, validation_loss:0.3622
# Epoch [69/200], average_loss:0.3603, validation_loss:0.3554
# Epoch [70/200], average_loss:0.3601, validation_loss:0.3586
# Epoch [71/200], average_loss:0.3599, validation_loss:0.3612
# Epoch [72/200], average_loss:0.3593, validation_loss:0.3623
# Epoch [73/200], average_loss:0.3576, validation_loss:0.3573
# Epoch [74/200], average_loss:0.3564, validation_loss:0.3656
# Epoch [75/200], average_loss:0.3561, validation_loss:0.3568
# Epoch [76/200], average_loss:0.3561, validation_loss:0.3548
# Epoch [77/200], average_loss:0.3555, validation_loss:0.3633
# Epoch [78/200], average_loss:0.3538, validation_loss:0.3576
# Epoch [79/200], average_loss:0.3534, validation_loss:0.3566
# Epoch [80/200], average_loss:0.3519, validation_loss:0.3546
# Epoch [81/200], average_loss:0.3517, validation_loss:0.3592
# Epoch [82/200], average_loss:0.3514, validation_loss:0.3541
# Epoch [83/200], average_loss:0.3496, validation_loss:0.3480
# Epoch [84/200], average_loss:0.3496, validation_loss:0.3607
# Epoch [85/200], average_loss:0.3496, validation_loss:0.3531
# Epoch [86/200], average_loss:0.3481, validation_loss:0.3467
# Epoch [87/200], average_loss:0.3467, validation_loss:0.3453
# Epoch [88/200], average_loss:0.3455, validation_loss:0.3519
# Epoch [89/200], average_loss:0.3459, validation_loss:0.3455
# Epoch [90/200], average_loss:0.3444, validation_loss:0.3479
# Epoch [91/200], average_loss:0.3442, validation_loss:0.3434
# Epoch [92/200], average_loss:0.3437, validation_loss:0.3440
# Epoch [93/200], average_loss:0.3435, validation_loss:0.3425
# Epoch [94/200], average_loss:0.3411, validation_loss:0.3399
# Epoch [95/200], average_loss:0.3418, validation_loss:0.3494
# Epoch [96/200], average_loss:0.3409, validation_loss:0.3397
# Epoch [97/200], average_loss:0.3398, validation_loss:0.3513
# Epoch [98/200], average_loss:0.3395, validation_loss:0.3416
# Epoch [99/200], average_loss:0.3381, validation_loss:0.3468
# Epoch [100/200], average_loss:0.3364, validation_loss:0.3439
# Epoch [101/200], average_loss:0.3368, validation_loss:0.3407
# Epoch [102/200], average_loss:0.3359, validation_loss:0.3357
# Epoch [103/200], average_loss:0.3350, validation_loss:0.3390
# Epoch [104/200], average_loss:0.3336, validation_loss:0.3416
# Epoch [105/200], average_loss:0.3345, validation_loss:0.3352
# Epoch [106/200], average_loss:0.3322, validation_loss:0.3396
# Epoch [107/200], average_loss:0.3319, validation_loss:0.3337
# Epoch [108/200], average_loss:0.3310, validation_loss:0.3373
# Epoch [109/200], average_loss:0.3315, validation_loss:0.3351
# Epoch [110/200], average_loss:0.3306, validation_loss:0.3405
# Epoch [111/200], average_loss:0.3289, validation_loss:0.3362
# Epoch [112/200], average_loss:0.3285, validation_loss:0.3335
# Epoch [113/200], average_loss:0.3272, validation_loss:0.3348
# Epoch [114/200], average_loss:0.3256, validation_loss:0.3319
# Epoch [115/200], average_loss:0.3263, validation_loss:0.3313
# Epoch [116/200], average_loss:0.3260, validation_loss:0.3378
# Epoch [117/200], average_loss:0.3244, validation_loss:0.3294
# Epoch [118/200], average_loss:0.3235, validation_loss:0.3306
# Epoch [119/200], average_loss:0.3212, validation_loss:0.3313
# Epoch [120/200], average_loss:0.3219, validation_loss:0.3299
# Epoch [121/200], average_loss:0.3218, validation_loss:0.3327
# Epoch [122/200], average_loss:0.3226, validation_loss:0.3295
# Epoch [123/200], average_loss:0.3193, validation_loss:0.3308
# Epoch [124/200], average_loss:0.3197, validation_loss:0.3285
# Epoch [125/200], average_loss:0.3186, validation_loss:0.3290
# Epoch [126/200], average_loss:0.3174, validation_loss:0.3250
# Epoch [127/200], average_loss:0.3174, validation_loss:0.3240
# Epoch [128/200], average_loss:0.3169, validation_loss:0.3219
# Epoch [129/200], average_loss:0.3151, validation_loss:0.3252
# Epoch [130/200], average_loss:0.3134, validation_loss:0.3315
# Epoch [131/200], average_loss:0.3133, validation_loss:0.3246
# Epoch [132/200], average_loss:0.3132, validation_loss:0.3282
# Epoch [133/200], average_loss:0.3126, validation_loss:0.3259
# Epoch [134/200], average_loss:0.3123, validation_loss:0.3271
# Epoch [135/200], average_loss:0.3112, validation_loss:0.3218
# Epoch [136/200], average_loss:0.3093, validation_loss:0.3181
# Epoch [137/200], average_loss:0.3086, validation_loss:0.3268
# Epoch [138/200], average_loss:0.3082, validation_loss:0.3187
# Epoch [139/200], average_loss:0.3069, validation_loss:0.3190
# Epoch [140/200], average_loss:0.3067, validation_loss:0.3286
# Epoch [141/200], average_loss:0.3053, validation_loss:0.3208
# Epoch [142/200], average_loss:0.3078, validation_loss:0.3167
# Epoch [143/200], average_loss:0.3042, validation_loss:0.3198
# Epoch [144/200], average_loss:0.3034, validation_loss:0.3245
# Epoch [145/200], average_loss:0.3016, validation_loss:0.3146
# Epoch [146/200], average_loss:0.3020, validation_loss:0.3224
# Epoch [147/200], average_loss:0.3006, validation_loss:0.3315
# Epoch [148/200], average_loss:0.2991, validation_loss:0.3187
# Epoch [149/200], average_loss:0.3001, validation_loss:0.3126
# Epoch [150/200], average_loss:0.2974, validation_loss:0.3131
# Epoch [151/200], average_loss:0.2960, validation_loss:0.3282
# Epoch [152/200], average_loss:0.2949, validation_loss:0.3157
# Epoch [153/200], average_loss:0.2943, validation_loss:0.3111
# Epoch [154/200], average_loss:0.2934, validation_loss:0.3107
# Epoch [155/200], average_loss:0.2935, validation_loss:0.3091
# Epoch [156/200], average_loss:0.2911, validation_loss:0.3095
# Epoch [157/200], average_loss:0.2897, validation_loss:0.3152
# Epoch [158/200], average_loss:0.2888, validation_loss:0.3066
# Epoch [159/200], average_loss:0.2884, validation_loss:0.3096
# Epoch [160/200], average_loss:0.2867, validation_loss:0.3072
# Epoch [161/200], average_loss:0.2864, validation_loss:0.3059
# Epoch [162/200], average_loss:0.2857, validation_loss:0.3039
# Epoch [163/200], average_loss:0.2839, validation_loss:0.3023
# Epoch [164/200], average_loss:0.2836, validation_loss:0.3019
# Epoch [165/200], average_loss:0.2827, validation_loss:0.3101
# Epoch [166/200], average_loss:0.2817, validation_loss:0.2988
# Epoch [167/200], average_loss:0.2793, validation_loss:0.3080
# Epoch [168/200], average_loss:0.2790, validation_loss:0.3001
# Epoch [169/200], average_loss:0.2777, validation_loss:0.2972
# Epoch [170/200], average_loss:0.2767, validation_loss:0.3157
# Epoch [171/200], average_loss:0.2761, validation_loss:0.2944
# Epoch [172/200], average_loss:0.2730, validation_loss:0.2970
# Epoch [173/200], average_loss:0.2734, validation_loss:0.3002
# Epoch [174/200], average_loss:0.2722, validation_loss:0.3024
# Epoch [175/200], average_loss:0.2704, validation_loss:0.3031
# Epoch [176/200], average_loss:0.2691, validation_loss:0.2916
# Epoch [177/200], average_loss:0.2671, validation_loss:0.2965
# Epoch [178/200], average_loss:0.2660, validation_loss:0.2895
# Epoch [179/200], average_loss:0.2653, validation_loss:0.2925
# Epoch [180/200], average_loss:0.2648, validation_loss:0.2945
# Epoch [181/200], average_loss:0.2623, validation_loss:0.2831
# Epoch [182/200], average_loss:0.2610, validation_loss:0.2860
# Epoch [183/200], average_loss:0.2620, validation_loss:0.2844
# Epoch [184/200], average_loss:0.2593, validation_loss:0.2815
# Epoch [185/200], average_loss:0.2591, validation_loss:0.2915
# Epoch [186/200], average_loss:0.2600, validation_loss:0.2810
# Epoch [187/200], average_loss:0.2569, validation_loss:0.2860
# Epoch [188/200], average_loss:0.2555, validation_loss:0.2788
# Epoch [189/200], average_loss:0.2545, validation_loss:0.2809
# Epoch [190/200], average_loss:0.2539, validation_loss:0.2881
# Epoch [191/200], average_loss:0.2534, validation_loss:0.2795
# Epoch [192/200], average_loss:0.2521, validation_loss:0.2758
# Epoch [193/200], average_loss:0.2507, validation_loss:0.2810
# Epoch [194/200], average_loss:0.2515, validation_loss:0.2895
# Epoch [195/200], average_loss:0.2487, validation_loss:0.2732
# Epoch [196/200], average_loss:0.2492, validation_loss:0.2827
# Epoch [197/200], average_loss:0.2471, validation_loss:0.2815
# Epoch [198/200], average_loss:0.2470, validation_loss:0.2826
# Epoch [199/200], average_loss:0.2464, validation_loss:0.2764
# Epoch [200/200], average_loss:0.2468, validation_loss:0.2716

# %%
loss_train = m1.loss_history["train"]
axe_t = np.arange(len(loss_train))/10
loss_val = m1.loss_history["validation"]
axe_v = np.arange(len(loss_val))
plt.figure(figsize=(25,18))
plt.plot(axe_t, loss_train, lw=0.5)
plt.plot(axe_v, loss_val, lw=0.5)
plt.ylabel("loss")
plt.xlabel("Epochs")
plt.show()

# %% [markdown]
# ## Batch size 300 + learning rate 1e-3 + Sigmoid

# %%
train_loader = torch.utils.data.DataLoader(dataset = train, batch_size=300, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset = test, batch_size=300, shuffle=True)

# %%
model2 = DNN(n_layers=2, neurons=[160, 128, 64], output_dim=4, activation=nn.Sigmoid(), dropout=False)

# %%
m2 = Trainer(
        model=model2,
        optimizer=torch.optim.Adam(model2.parameters(), lr=1e-3),
        loss_function=nn.CrossEntropyLoss(),
        verbose=True
        )
# Out:
# cuda:0

# %%
lh = m2(epochs=200, train_loader=train_loader, validation_loader=test_loader)
# Out:
# Epoch [1/200], average_loss:0.8584, validation_loss:0.7280
# Epoch [2/200], average_loss:0.6474, validation_loss:0.5807
# Epoch [3/200], average_loss:0.5660, validation_loss:0.5467
# Epoch [4/200], average_loss:0.5385, validation_loss:0.5214
# Epoch [5/200], average_loss:0.5216, validation_loss:0.5093
# Epoch [6/200], average_loss:0.5097, validation_loss:0.5010
# Epoch [7/200], average_loss:0.4995, validation_loss:0.4976
# Epoch [8/200], average_loss:0.4937, validation_loss:0.4856
# Epoch [9/200], average_loss:0.4854, validation_loss:0.4743
# Epoch [10/200], average_loss:0.4765, validation_loss:0.4672
# Epoch [11/200], average_loss:0.4717, validation_loss:0.4616
# Epoch [12/200], average_loss:0.4675, validation_loss:0.4595
# Epoch [13/200], average_loss:0.4641, validation_loss:0.4551
# Epoch [14/200], average_loss:0.4598, validation_loss:0.4552
# Epoch [15/200], average_loss:0.4580, validation_loss:0.4479
# Epoch [16/200], average_loss:0.4545, validation_loss:0.4561
# Epoch [17/200], average_loss:0.4528, validation_loss:0.4427
# Epoch [18/200], average_loss:0.4506, validation_loss:0.4416
# Epoch [19/200], average_loss:0.4486, validation_loss:0.4390
# Epoch [20/200], average_loss:0.4453, validation_loss:0.4382
# Epoch [21/200], average_loss:0.4463, validation_loss:0.4430
# Epoch [22/200], average_loss:0.4427, validation_loss:0.4334
# Epoch [23/200], average_loss:0.4428, validation_loss:0.4359
# Epoch [24/200], average_loss:0.4382, validation_loss:0.4369
# Epoch [25/200], average_loss:0.4393, validation_loss:0.4366
# Epoch [26/200], average_loss:0.4368, validation_loss:0.4307
# Epoch [27/200], average_loss:0.4357, validation_loss:0.4381
# Epoch [28/200], average_loss:0.4323, validation_loss:0.4224
# Epoch [29/200], average_loss:0.4326, validation_loss:0.4249
# Epoch [30/200], average_loss:0.4308, validation_loss:0.4260
# Epoch [31/200], average_loss:0.4287, validation_loss:0.4190
# Epoch [32/200], average_loss:0.4268, validation_loss:0.4387
# Epoch [33/200], average_loss:0.4259, validation_loss:0.4163
# Epoch [34/200], average_loss:0.4248, validation_loss:0.4161
# Epoch [35/200], average_loss:0.4236, validation_loss:0.4236
# Epoch [36/200], average_loss:0.4204, validation_loss:0.4143
# Epoch [37/200], average_loss:0.4227, validation_loss:0.4111
# Epoch [38/200], average_loss:0.4202, validation_loss:0.4111
# Epoch [39/200], average_loss:0.4178, validation_loss:0.4139
# Epoch [40/200], average_loss:0.4164, validation_loss:0.4107
# Epoch [41/200], average_loss:0.4147, validation_loss:0.4137
# Epoch [42/200], average_loss:0.4143, validation_loss:0.4060
# Epoch [43/200], average_loss:0.4140, validation_loss:0.4159
# Epoch [44/200], average_loss:0.4112, validation_loss:0.4066
# Epoch [45/200], average_loss:0.4119, validation_loss:0.4031
# Epoch [46/200], average_loss:0.4100, validation_loss:0.4334
# Epoch [47/200], average_loss:0.4093, validation_loss:0.4044
# Epoch [48/200], average_loss:0.4071, validation_loss:0.3977
# Epoch [49/200], average_loss:0.4077, validation_loss:0.4020
# Epoch [50/200], average_loss:0.4070, validation_loss:0.3953
# Epoch [51/200], average_loss:0.4059, validation_loss:0.4020
# Epoch [52/200], average_loss:0.4046, validation_loss:0.3988
# Epoch [53/200], average_loss:0.4026, validation_loss:0.3934
# Epoch [54/200], average_loss:0.4018, validation_loss:0.4316
# Epoch [55/200], average_loss:0.4019, validation_loss:0.3980
# Epoch [56/200], average_loss:0.3995, validation_loss:0.3926
# Epoch [57/200], average_loss:0.3991, validation_loss:0.3886
# Epoch [58/200], average_loss:0.3975, validation_loss:0.3896
# Epoch [59/200], average_loss:0.3983, validation_loss:0.3884
# Epoch [60/200], average_loss:0.3980, validation_loss:0.3897
# Epoch [61/200], average_loss:0.3952, validation_loss:0.3956
# Epoch [62/200], average_loss:0.3970, validation_loss:0.3905
# Epoch [63/200], average_loss:0.3941, validation_loss:0.3870
# Epoch [64/200], average_loss:0.3935, validation_loss:0.3854
# Epoch [65/200], average_loss:0.3918, validation_loss:0.3885
# Epoch [66/200], average_loss:0.3934, validation_loss:0.3888
# Epoch [67/200], average_loss:0.3920, validation_loss:0.3865
# Epoch [68/200], average_loss:0.3904, validation_loss:0.3839
# Epoch [69/200], average_loss:0.3895, validation_loss:0.3819
# Epoch [70/200], average_loss:0.3896, validation_loss:0.3868
# Epoch [71/200], average_loss:0.3892, validation_loss:0.3851
# Epoch [72/200], average_loss:0.3881, validation_loss:0.3841
# Epoch [73/200], average_loss:0.3867, validation_loss:0.3825
# Epoch [74/200], average_loss:0.3868, validation_loss:0.3793
# Epoch [75/200], average_loss:0.3864, validation_loss:0.3803
# Epoch [76/200], average_loss:0.3839, validation_loss:0.3816
# Epoch [77/200], average_loss:0.3833, validation_loss:0.3773
# Epoch [78/200], average_loss:0.3836, validation_loss:0.3777
# Epoch [79/200], average_loss:0.3827, validation_loss:0.3755
# Epoch [80/200], average_loss:0.3838, validation_loss:0.3736
# Epoch [81/200], average_loss:0.3825, validation_loss:0.3801
# Epoch [82/200], average_loss:0.3830, validation_loss:0.3901
# Epoch [83/200], average_loss:0.3817, validation_loss:0.3804
# Epoch [84/200], average_loss:0.3804, validation_loss:0.3731
# Epoch [85/200], average_loss:0.3795, validation_loss:0.3803
# Epoch [86/200], average_loss:0.3793, validation_loss:0.3743
# Epoch [87/200], average_loss:0.3775, validation_loss:0.3756
# Epoch [88/200], average_loss:0.3780, validation_loss:0.3733
# Epoch [89/200], average_loss:0.3780, validation_loss:0.3701
# Epoch [90/200], average_loss:0.3760, validation_loss:0.3742
# Epoch [91/200], average_loss:0.3749, validation_loss:0.3750
# Epoch [92/200], average_loss:0.3765, validation_loss:0.3713
# Epoch [93/200], average_loss:0.3752, validation_loss:0.3705
# Epoch [94/200], average_loss:0.3743, validation_loss:0.3801
# Epoch [95/200], average_loss:0.3755, validation_loss:0.3717
# Epoch [96/200], average_loss:0.3730, validation_loss:0.3817
# Epoch [97/200], average_loss:0.3725, validation_loss:0.3690
# Epoch [98/200], average_loss:0.3726, validation_loss:0.3678
# Epoch [99/200], average_loss:0.3729, validation_loss:0.3668
# Epoch [100/200], average_loss:0.3711, validation_loss:0.3737
# Epoch [101/200], average_loss:0.3704, validation_loss:0.3834
# Epoch [102/200], average_loss:0.3714, validation_loss:0.3761
# Epoch [103/200], average_loss:0.3696, validation_loss:0.3701
# Epoch [104/200], average_loss:0.3680, validation_loss:0.3661
# Epoch [105/200], average_loss:0.3702, validation_loss:0.3715
# Epoch [106/200], average_loss:0.3705, validation_loss:0.3715
# Epoch [107/200], average_loss:0.3685, validation_loss:0.3913
# Epoch [108/200], average_loss:0.3685, validation_loss:0.3672
# Epoch [109/200], average_loss:0.3677, validation_loss:0.3644
# Epoch [110/200], average_loss:0.3667, validation_loss:0.3706
# Epoch [111/200], average_loss:0.3656, validation_loss:0.3640
# Epoch [112/200], average_loss:0.3672, validation_loss:0.3632
# Epoch [113/200], average_loss:0.3651, validation_loss:0.3684
# Epoch [114/200], average_loss:0.3631, validation_loss:0.3663
# Epoch [115/200], average_loss:0.3653, validation_loss:0.3623
# Epoch [116/200], average_loss:0.3640, validation_loss:0.3675
# Epoch [117/200], average_loss:0.3639, validation_loss:0.3708
# Epoch [118/200], average_loss:0.3634, validation_loss:0.3649
# Epoch [119/200], average_loss:0.3638, validation_loss:0.3604
# Epoch [120/200], average_loss:0.3618, validation_loss:0.3723
# Epoch [121/200], average_loss:0.3622, validation_loss:0.3607
# Epoch [122/200], average_loss:0.3621, validation_loss:0.3634
# Epoch [123/200], average_loss:0.3612, validation_loss:0.3600
# Epoch [124/200], average_loss:0.3598, validation_loss:0.3631
# Epoch [125/200], average_loss:0.3600, validation_loss:0.3638
# Epoch [126/200], average_loss:0.3594, validation_loss:0.3587
# Epoch [127/200], average_loss:0.3606, validation_loss:0.3618
# Epoch [128/200], average_loss:0.3582, validation_loss:0.3676
# Epoch [129/200], average_loss:0.3584, validation_loss:0.3629
# Epoch [130/200], average_loss:0.3598, validation_loss:0.3588
# Epoch [131/200], average_loss:0.3586, validation_loss:0.3549
# Epoch [132/200], average_loss:0.3568, validation_loss:0.3596
# Epoch [133/200], average_loss:0.3575, validation_loss:0.3575
# Epoch [134/200], average_loss:0.3558, validation_loss:0.3557
# Epoch [135/200], average_loss:0.3555, validation_loss:0.3580
# Epoch [136/200], average_loss:0.3552, validation_loss:0.3567
# Epoch [137/200], average_loss:0.3557, validation_loss:0.3560
# Epoch [138/200], average_loss:0.3554, validation_loss:0.3617
# Epoch [139/200], average_loss:0.3544, validation_loss:0.3556
# Epoch [140/200], average_loss:0.3537, validation_loss:0.3541
# Epoch [141/200], average_loss:0.3528, validation_loss:0.3571
# Epoch [142/200], average_loss:0.3535, validation_loss:0.3612
# Epoch [143/200], average_loss:0.3535, validation_loss:0.3545
# Epoch [144/200], average_loss:0.3535, validation_loss:0.3573
# Epoch [145/200], average_loss:0.3508, validation_loss:0.3522
# Epoch [146/200], average_loss:0.3511, validation_loss:0.3611
# Epoch [147/200], average_loss:0.3516, validation_loss:0.3690
# Epoch [148/200], average_loss:0.3514, validation_loss:0.3574
# Epoch [149/200], average_loss:0.3509, validation_loss:0.3567
# Epoch [150/200], average_loss:0.3509, validation_loss:0.3563
# Epoch [151/200], average_loss:0.3509, validation_loss:0.3503
# Epoch [152/200], average_loss:0.3496, validation_loss:0.3558
# Epoch [153/200], average_loss:0.3476, validation_loss:0.3527
# Epoch [154/200], average_loss:0.3507, validation_loss:0.3541
# Epoch [155/200], average_loss:0.3483, validation_loss:0.3526
# Epoch [156/200], average_loss:0.3478, validation_loss:0.3498
# Epoch [157/200], average_loss:0.3478, validation_loss:0.3517
# Epoch [158/200], average_loss:0.3480, validation_loss:0.3556
# Epoch [159/200], average_loss:0.3477, validation_loss:0.3511
# Epoch [160/200], average_loss:0.3461, validation_loss:0.3486
# Epoch [161/200], average_loss:0.3478, validation_loss:0.3492
# Epoch [162/200], average_loss:0.3452, validation_loss:0.3497
# Epoch [163/200], average_loss:0.3460, validation_loss:0.3570
# Epoch [164/200], average_loss:0.3463, validation_loss:0.3517
# Epoch [165/200], average_loss:0.3454, validation_loss:0.3492
# Epoch [166/200], average_loss:0.3437, validation_loss:0.3508
# Epoch [167/200], average_loss:0.3431, validation_loss:0.3492
# Epoch [168/200], average_loss:0.3430, validation_loss:0.3525
# Epoch [169/200], average_loss:0.3429, validation_loss:0.3522
# Epoch [170/200], average_loss:0.3435, validation_loss:0.3482
# Epoch [171/200], average_loss:0.3432, validation_loss:0.3618
# Epoch [172/200], average_loss:0.3427, validation_loss:0.3462
# Epoch [173/200], average_loss:0.3422, validation_loss:0.3655
# Epoch [174/200], average_loss:0.3430, validation_loss:0.3519
# Epoch [175/200], average_loss:0.3419, validation_loss:0.3512
# Epoch [176/200], average_loss:0.3413, validation_loss:0.3463
# Epoch [177/200], average_loss:0.3398, validation_loss:0.3472
# Epoch [178/200], average_loss:0.3415, validation_loss:0.3622
# Epoch [179/200], average_loss:0.3396, validation_loss:0.3463
# Epoch [180/200], average_loss:0.3388, validation_loss:0.3407
# Epoch [181/200], average_loss:0.3383, validation_loss:0.3527
# Epoch [182/200], average_loss:0.3401, validation_loss:0.3445
# Epoch [183/200], average_loss:0.3388, validation_loss:0.3484
# Epoch [184/200], average_loss:0.3369, validation_loss:0.3436
# Epoch [185/200], average_loss:0.3381, validation_loss:0.3411
# Epoch [186/200], average_loss:0.3363, validation_loss:0.3444
# Epoch [187/200], average_loss:0.3367, validation_loss:0.3455
# Epoch [188/200], average_loss:0.3359, validation_loss:0.3411
# Epoch [189/200], average_loss:0.3352, validation_loss:0.3451
# Epoch [190/200], average_loss:0.3378, validation_loss:0.3484
# Epoch [191/200], average_loss:0.3357, validation_loss:0.3452
# Epoch [192/200], average_loss:0.3345, validation_loss:0.3414
# Epoch [193/200], average_loss:0.3347, validation_loss:0.3421
# Epoch [194/200], average_loss:0.3337, validation_loss:0.3517
# Epoch [195/200], average_loss:0.3342, validation_loss:0.3423
# Epoch [196/200], average_loss:0.3335, validation_loss:0.3435
# Epoch [197/200], average_loss:0.3332, validation_loss:0.3420
# Epoch [198/200], average_loss:0.3337, validation_loss:0.3407
# Epoch [199/200], average_loss:0.3347, validation_loss:0.3425
# Epoch [200/200], average_loss:0.3323, validation_loss:0.3403

# %%
plot_loss(m2)

# %% [markdown]
# ## Batch size 100 + learning rate 1e-4 + Sigmoid

# %%
train_loader = torch.utils.data.DataLoader(dataset = train, batch_size=100, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset = test, batch_size=100, shuffle=True)

# %%
model3 = DNN(n_layers=2, neurons=[160, 128, 64], output_dim=4, activation=nn.Sigmoid(), dropout=False)

# %%
m3 = Trainer(
        model=model3,
        optimizer=torch.optim.Adam(model3.parameters(), lr=1e-4),
        loss_function=nn.CrossEntropyLoss(),
        verbose=True
        )
# Out:
# cuda:0

# %%
lh = m3(epochs=200, train_loader=train_loader, validation_loader=test_loader)
# Out:
# Epoch [1/200], average_loss:0.9292, validation_loss:0.8749
# Epoch [2/200], average_loss:0.8654, validation_loss:0.8457
# Epoch [3/200], average_loss:0.8208, validation_loss:0.7816
# Epoch [4/200], average_loss:0.7483, validation_loss:0.7076
# Epoch [5/200], average_loss:0.6887, validation_loss:0.6609
# Epoch [6/200], average_loss:0.6528, validation_loss:0.6303
# Epoch [7/200], average_loss:0.6276, validation_loss:0.6082
# Epoch [8/200], average_loss:0.6064, validation_loss:0.5898
# Epoch [9/200], average_loss:0.5887, validation_loss:0.5716
# Epoch [10/200], average_loss:0.5741, validation_loss:0.5592
# Epoch [11/200], average_loss:0.5630, validation_loss:0.5499
# Epoch [12/200], average_loss:0.5538, validation_loss:0.5417
# Epoch [13/200], average_loss:0.5469, validation_loss:0.5355
# Epoch [14/200], average_loss:0.5413, validation_loss:0.5303
# Epoch [15/200], average_loss:0.5368, validation_loss:0.5256
# Epoch [16/200], average_loss:0.5327, validation_loss:0.5224
# Epoch [17/200], average_loss:0.5292, validation_loss:0.5213
# Epoch [18/200], average_loss:0.5263, validation_loss:0.5166
# Epoch [19/200], average_loss:0.5235, validation_loss:0.5152
# Epoch [20/200], average_loss:0.5209, validation_loss:0.5132
# Epoch [21/200], average_loss:0.5188, validation_loss:0.5104
# Epoch [22/200], average_loss:0.5164, validation_loss:0.5109
# Epoch [23/200], average_loss:0.5145, validation_loss:0.5062
# Epoch [24/200], average_loss:0.5124, validation_loss:0.5049
# Epoch [25/200], average_loss:0.5106, validation_loss:0.5027
# Epoch [26/200], average_loss:0.5089, validation_loss:0.5018
# Epoch [27/200], average_loss:0.5070, validation_loss:0.5001
# Epoch [28/200], average_loss:0.5054, validation_loss:0.4968
# Epoch [29/200], average_loss:0.5037, validation_loss:0.4994
# Epoch [30/200], average_loss:0.5023, validation_loss:0.4956
# Epoch [31/200], average_loss:0.5005, validation_loss:0.4934
# Epoch [32/200], average_loss:0.4988, validation_loss:0.4927
# Epoch [33/200], average_loss:0.4977, validation_loss:0.4902
# Epoch [34/200], average_loss:0.4961, validation_loss:0.4899
# Epoch [35/200], average_loss:0.4948, validation_loss:0.4883
# Epoch [36/200], average_loss:0.4935, validation_loss:0.4871
# Epoch [37/200], average_loss:0.4918, validation_loss:0.4859
# Epoch [38/200], average_loss:0.4908, validation_loss:0.4839
# Epoch [39/200], average_loss:0.4893, validation_loss:0.4834
# Epoch [40/200], average_loss:0.4879, validation_loss:0.4813
# Epoch [41/200], average_loss:0.4867, validation_loss:0.4810
# Epoch [42/200], average_loss:0.4854, validation_loss:0.4791
# Epoch [43/200], average_loss:0.4842, validation_loss:0.4778
# Epoch [44/200], average_loss:0.4827, validation_loss:0.4761
# Epoch [45/200], average_loss:0.4814, validation_loss:0.4767
# Epoch [46/200], average_loss:0.4805, validation_loss:0.4755
# Epoch [47/200], average_loss:0.4787, validation_loss:0.4741
# Epoch [48/200], average_loss:0.4776, validation_loss:0.4724
# Epoch [49/200], average_loss:0.4767, validation_loss:0.4710
# Epoch [50/200], average_loss:0.4754, validation_loss:0.4696
# Epoch [51/200], average_loss:0.4743, validation_loss:0.4683
# Epoch [52/200], average_loss:0.4728, validation_loss:0.4691
# Epoch [53/200], average_loss:0.4720, validation_loss:0.4669
# Epoch [54/200], average_loss:0.4712, validation_loss:0.4647
# Epoch [55/200], average_loss:0.4702, validation_loss:0.4662
# Epoch [56/200], average_loss:0.4688, validation_loss:0.4632
# Epoch [57/200], average_loss:0.4680, validation_loss:0.4613
# Epoch [58/200], average_loss:0.4670, validation_loss:0.4616
# Epoch [59/200], average_loss:0.4659, validation_loss:0.4600
# Epoch [60/200], average_loss:0.4650, validation_loss:0.4593
# Epoch [61/200], average_loss:0.4642, validation_loss:0.4586
# Epoch [62/200], average_loss:0.4632, validation_loss:0.4578
# Epoch [63/200], average_loss:0.4626, validation_loss:0.4575
# Epoch [64/200], average_loss:0.4616, validation_loss:0.4559
# Epoch [65/200], average_loss:0.4609, validation_loss:0.4544
# Epoch [66/200], average_loss:0.4601, validation_loss:0.4541
# Epoch [67/200], average_loss:0.4595, validation_loss:0.4531
# Epoch [68/200], average_loss:0.4590, validation_loss:0.4527
# Epoch [69/200], average_loss:0.4582, validation_loss:0.4516
# Epoch [70/200], average_loss:0.4576, validation_loss:0.4509
# Epoch [71/200], average_loss:0.4572, validation_loss:0.4504
# Epoch [72/200], average_loss:0.4562, validation_loss:0.4499
# Epoch [73/200], average_loss:0.4554, validation_loss:0.4493
# Epoch [74/200], average_loss:0.4551, validation_loss:0.4496
# Epoch [75/200], average_loss:0.4547, validation_loss:0.4482
# Epoch [76/200], average_loss:0.4538, validation_loss:0.4484
# Epoch [77/200], average_loss:0.4533, validation_loss:0.4465
# Epoch [78/200], average_loss:0.4527, validation_loss:0.4476
# Epoch [79/200], average_loss:0.4523, validation_loss:0.4469
# Epoch [80/200], average_loss:0.4516, validation_loss:0.4463
# Epoch [81/200], average_loss:0.4511, validation_loss:0.4444
# Epoch [82/200], average_loss:0.4508, validation_loss:0.4484
# Epoch [83/200], average_loss:0.4501, validation_loss:0.4432
# Epoch [84/200], average_loss:0.4496, validation_loss:0.4468
# Epoch [85/200], average_loss:0.4489, validation_loss:0.4425
# Epoch [86/200], average_loss:0.4489, validation_loss:0.4423
# Epoch [87/200], average_loss:0.4483, validation_loss:0.4412
# Epoch [88/200], average_loss:0.4480, validation_loss:0.4410
# Epoch [89/200], average_loss:0.4472, validation_loss:0.4406
# Epoch [90/200], average_loss:0.4473, validation_loss:0.4406
# Epoch [91/200], average_loss:0.4465, validation_loss:0.4409
# Epoch [92/200], average_loss:0.4458, validation_loss:0.4401
# Epoch [93/200], average_loss:0.4454, validation_loss:0.4391
# Epoch [94/200], average_loss:0.4452, validation_loss:0.4398
# Epoch [95/200], average_loss:0.4446, validation_loss:0.4389
# Epoch [96/200], average_loss:0.4443, validation_loss:0.4369
# Epoch [97/200], average_loss:0.4440, validation_loss:0.4372
# Epoch [98/200], average_loss:0.4432, validation_loss:0.4362
# Epoch [99/200], average_loss:0.4431, validation_loss:0.4358
# Epoch [100/200], average_loss:0.4427, validation_loss:0.4353
# Epoch [101/200], average_loss:0.4420, validation_loss:0.4359
# Epoch [102/200], average_loss:0.4420, validation_loss:0.4359
# Epoch [103/200], average_loss:0.4411, validation_loss:0.4340
# Epoch [104/200], average_loss:0.4409, validation_loss:0.4396
# Epoch [105/200], average_loss:0.4405, validation_loss:0.4354
# Epoch [106/200], average_loss:0.4405, validation_loss:0.4338
# Epoch [107/200], average_loss:0.4398, validation_loss:0.4323
# Epoch [108/200], average_loss:0.4393, validation_loss:0.4345
# Epoch [109/200], average_loss:0.4394, validation_loss:0.4322
# Epoch [110/200], average_loss:0.4386, validation_loss:0.4318
# Epoch [111/200], average_loss:0.4383, validation_loss:0.4336
# Epoch [112/200], average_loss:0.4380, validation_loss:0.4314
# Epoch [113/200], average_loss:0.4379, validation_loss:0.4302
# Epoch [114/200], average_loss:0.4372, validation_loss:0.4296
# Epoch [115/200], average_loss:0.4368, validation_loss:0.4290
# Epoch [116/200], average_loss:0.4363, validation_loss:0.4292
# Epoch [117/200], average_loss:0.4358, validation_loss:0.4300
# Epoch [118/200], average_loss:0.4359, validation_loss:0.4286
# Epoch [119/200], average_loss:0.4355, validation_loss:0.4276
# Epoch [120/200], average_loss:0.4345, validation_loss:0.4279
# Epoch [121/200], average_loss:0.4346, validation_loss:0.4285
# Epoch [122/200], average_loss:0.4342, validation_loss:0.4262
# Epoch [123/200], average_loss:0.4338, validation_loss:0.4258
# Epoch [124/200], average_loss:0.4333, validation_loss:0.4263
# Epoch [125/200], average_loss:0.4329, validation_loss:0.4260
# Epoch [126/200], average_loss:0.4329, validation_loss:0.4258
# Epoch [127/200], average_loss:0.4323, validation_loss:0.4252
# Epoch [128/200], average_loss:0.4316, validation_loss:0.4245
# Epoch [129/200], average_loss:0.4313, validation_loss:0.4244
# Epoch [130/200], average_loss:0.4306, validation_loss:0.4231
# Epoch [131/200], average_loss:0.4308, validation_loss:0.4238
# Epoch [132/200], average_loss:0.4296, validation_loss:0.4238
# Epoch [133/200], average_loss:0.4295, validation_loss:0.4216
# Epoch [134/200], average_loss:0.4291, validation_loss:0.4210
# Epoch [135/200], average_loss:0.4286, validation_loss:0.4205
# Epoch [136/200], average_loss:0.4281, validation_loss:0.4217
# Epoch [137/200], average_loss:0.4276, validation_loss:0.4208
# Epoch [138/200], average_loss:0.4272, validation_loss:0.4191
# Epoch [139/200], average_loss:0.4266, validation_loss:0.4187
# Epoch [140/200], average_loss:0.4268, validation_loss:0.4204
# Epoch [141/200], average_loss:0.4263, validation_loss:0.4188
# Epoch [142/200], average_loss:0.4259, validation_loss:0.4225
# Epoch [143/200], average_loss:0.4253, validation_loss:0.4186
# Epoch [144/200], average_loss:0.4250, validation_loss:0.4179
# Epoch [145/200], average_loss:0.4245, validation_loss:0.4164
# Epoch [146/200], average_loss:0.4243, validation_loss:0.4182
# Epoch [147/200], average_loss:0.4242, validation_loss:0.4176
# Epoch [148/200], average_loss:0.4234, validation_loss:0.4164
# Epoch [149/200], average_loss:0.4232, validation_loss:0.4164
# Epoch [150/200], average_loss:0.4229, validation_loss:0.4153
# Epoch [151/200], average_loss:0.4224, validation_loss:0.4143
# Epoch [152/200], average_loss:0.4220, validation_loss:0.4151
# Epoch [153/200], average_loss:0.4221, validation_loss:0.4148
# Epoch [154/200], average_loss:0.4215, validation_loss:0.4178
# Epoch [155/200], average_loss:0.4213, validation_loss:0.4138
# Epoch [156/200], average_loss:0.4213, validation_loss:0.4141
# Epoch [157/200], average_loss:0.4208, validation_loss:0.4131
# Epoch [158/200], average_loss:0.4205, validation_loss:0.4133
# Epoch [159/200], average_loss:0.4200, validation_loss:0.4127
# Epoch [160/200], average_loss:0.4195, validation_loss:0.4128
# Epoch [161/200], average_loss:0.4197, validation_loss:0.4121
# Epoch [162/200], average_loss:0.4189, validation_loss:0.4122
# Epoch [163/200], average_loss:0.4187, validation_loss:0.4128
# Epoch [164/200], average_loss:0.4186, validation_loss:0.4111
# Epoch [165/200], average_loss:0.4184, validation_loss:0.4116
# Epoch [166/200], average_loss:0.4178, validation_loss:0.4106
# Epoch [167/200], average_loss:0.4178, validation_loss:0.4101
# Epoch [168/200], average_loss:0.4176, validation_loss:0.4099
# Epoch [169/200], average_loss:0.4169, validation_loss:0.4108
# Epoch [170/200], average_loss:0.4166, validation_loss:0.4108
# Epoch [171/200], average_loss:0.4162, validation_loss:0.4094
# Epoch [172/200], average_loss:0.4162, validation_loss:0.4097
# Epoch [173/200], average_loss:0.4159, validation_loss:0.4095
# Epoch [174/200], average_loss:0.4157, validation_loss:0.4088
# Epoch [175/200], average_loss:0.4153, validation_loss:0.4078
# Epoch [176/200], average_loss:0.4150, validation_loss:0.4084
# Epoch [177/200], average_loss:0.4148, validation_loss:0.4075
# Epoch [178/200], average_loss:0.4147, validation_loss:0.4062
# Epoch [179/200], average_loss:0.4145, validation_loss:0.4070
# Epoch [180/200], average_loss:0.4140, validation_loss:0.4074
# Epoch [181/200], average_loss:0.4136, validation_loss:0.4072
# Epoch [182/200], average_loss:0.4136, validation_loss:0.4065
# Epoch [183/200], average_loss:0.4132, validation_loss:0.4061
# Epoch [184/200], average_loss:0.4129, validation_loss:0.4074
# Epoch [185/200], average_loss:0.4131, validation_loss:0.4077
# Epoch [186/200], average_loss:0.4125, validation_loss:0.4052
# Epoch [187/200], average_loss:0.4123, validation_loss:0.4053
# Epoch [188/200], average_loss:0.4120, validation_loss:0.4064
# Epoch [189/200], average_loss:0.4116, validation_loss:0.4074
# Epoch [190/200], average_loss:0.4116, validation_loss:0.4053
# Epoch [191/200], average_loss:0.4111, validation_loss:0.4043
# Epoch [192/200], average_loss:0.4114, validation_loss:0.4041
# Epoch [193/200], average_loss:0.4110, validation_loss:0.4042
# Epoch [194/200], average_loss:0.4103, validation_loss:0.4068
# Epoch [195/200], average_loss:0.4102, validation_loss:0.4036
# Epoch [196/200], average_loss:0.4103, validation_loss:0.4033
# Epoch [197/200], average_loss:0.4097, validation_loss:0.4030
# Epoch [198/200], average_loss:0.4098, validation_loss:0.4024
# Epoch [199/200], average_loss:0.4094, validation_loss:0.4021
# Epoch [200/200], average_loss:0.4092, validation_loss:0.4053

# %%
plot_loss(m3)

# %% [markdown]
# ## Batch size 300 + learning rate 1e-4 + Sigmoid

# %%
train_loader = torch.utils.data.DataLoader(dataset = train, batch_size=300, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset = test, batch_size=300, shuffle=True)

# %%
model4 = DNN(n_layers=2, neurons=[160, 128, 64], output_dim=4, activation=nn.Sigmoid(), dropout=False)

# %%
m4 = Trainer(
        model=model4,
        optimizer=torch.optim.Adam(model4.parameters(), lr=1e-4),
        loss_function=nn.CrossEntropyLoss(),
        verbose=True
        )
# Out:
# cuda:0

# %%
lh = m4(epochs=200, train_loader=train_loader, validation_loader=test_loader)
# Out:
# Epoch [1/200], average_loss:1.0396, validation_loss:0.9221
# Epoch [2/200], average_loss:0.9026, validation_loss:0.8847
# Epoch [3/200], average_loss:0.8804, validation_loss:0.8686
# Epoch [4/200], average_loss:0.8639, validation_loss:0.8500
# Epoch [5/200], average_loss:0.8417, validation_loss:0.8252
# Epoch [6/200], average_loss:0.8161, validation_loss:0.7964
# Epoch [7/200], average_loss:0.7854, validation_loss:0.7654
# Epoch [8/200], average_loss:0.7553, validation_loss:0.7349
# Epoch [9/200], average_loss:0.7281, validation_loss:0.7098
# Epoch [10/200], average_loss:0.7057, validation_loss:0.6885
# Epoch [11/200], average_loss:0.6873, validation_loss:0.6704
# Epoch [12/200], average_loss:0.6711, validation_loss:0.6550
# Epoch [13/200], average_loss:0.6560, validation_loss:0.6402
# Epoch [14/200], average_loss:0.6415, validation_loss:0.6268
# Epoch [15/200], average_loss:0.6286, validation_loss:0.6137
# Epoch [16/200], average_loss:0.6176, validation_loss:0.6016
# Epoch [17/200], average_loss:0.6054, validation_loss:0.5915
# Epoch [18/200], average_loss:0.5959, validation_loss:0.5819
# Epoch [19/200], average_loss:0.5862, validation_loss:0.5728
# Epoch [20/200], average_loss:0.5786, validation_loss:0.5655
# Epoch [21/200], average_loss:0.5709, validation_loss:0.5588
# Epoch [22/200], average_loss:0.5647, validation_loss:0.5526
# Epoch [23/200], average_loss:0.5595, validation_loss:0.5481
# Epoch [24/200], average_loss:0.5545, validation_loss:0.5430
# Epoch [25/200], average_loss:0.5504, validation_loss:0.5395
# Epoch [26/200], average_loss:0.5470, validation_loss:0.5367
# Epoch [27/200], average_loss:0.5436, validation_loss:0.5336
# Epoch [28/200], average_loss:0.5410, validation_loss:0.5308
# Epoch [29/200], average_loss:0.5380, validation_loss:0.5284
# Epoch [30/200], average_loss:0.5359, validation_loss:0.5261
# Epoch [31/200], average_loss:0.5331, validation_loss:0.5237
# Epoch [32/200], average_loss:0.5317, validation_loss:0.5222
# Epoch [33/200], average_loss:0.5294, validation_loss:0.5204
# Epoch [34/200], average_loss:0.5277, validation_loss:0.5190
# Epoch [35/200], average_loss:0.5262, validation_loss:0.5171
# Epoch [36/200], average_loss:0.5245, validation_loss:0.5163
# Epoch [37/200], average_loss:0.5231, validation_loss:0.5148
# Epoch [38/200], average_loss:0.5218, validation_loss:0.5132
# Epoch [39/200], average_loss:0.5206, validation_loss:0.5119
# Epoch [40/200], average_loss:0.5197, validation_loss:0.5104
# Epoch [41/200], average_loss:0.5178, validation_loss:0.5094
# Epoch [42/200], average_loss:0.5162, validation_loss:0.5087
# Epoch [43/200], average_loss:0.5148, validation_loss:0.5070
# Epoch [44/200], average_loss:0.5140, validation_loss:0.5059
# Epoch [45/200], average_loss:0.5129, validation_loss:0.5051
# Epoch [46/200], average_loss:0.5121, validation_loss:0.5045
# Epoch [47/200], average_loss:0.5103, validation_loss:0.5031
# Epoch [48/200], average_loss:0.5105, validation_loss:0.5021
# Epoch [49/200], average_loss:0.5087, validation_loss:0.5010
# Epoch [50/200], average_loss:0.5075, validation_loss:0.5002
# Epoch [51/200], average_loss:0.5067, validation_loss:0.4993
# Epoch [52/200], average_loss:0.5067, validation_loss:0.4984
# Epoch [53/200], average_loss:0.5046, validation_loss:0.4988
# Epoch [54/200], average_loss:0.5037, validation_loss:0.4970
# Epoch [55/200], average_loss:0.5021, validation_loss:0.4958
# Epoch [56/200], average_loss:0.5023, validation_loss:0.4949
# Epoch [57/200], average_loss:0.5001, validation_loss:0.4933
# Epoch [58/200], average_loss:0.4997, validation_loss:0.4927
# Epoch [59/200], average_loss:0.4982, validation_loss:0.4920
# Epoch [60/200], average_loss:0.4976, validation_loss:0.4932
# Epoch [61/200], average_loss:0.4979, validation_loss:0.4905
# Epoch [62/200], average_loss:0.4958, validation_loss:0.4901
# Epoch [63/200], average_loss:0.4956, validation_loss:0.4893
# Epoch [64/200], average_loss:0.4946, validation_loss:0.4884
# Epoch [65/200], average_loss:0.4944, validation_loss:0.4876
# Epoch [66/200], average_loss:0.4930, validation_loss:0.4863
# Epoch [67/200], average_loss:0.4913, validation_loss:0.4851
# Epoch [68/200], average_loss:0.4908, validation_loss:0.4849
# Epoch [69/200], average_loss:0.4905, validation_loss:0.4839
# Epoch [70/200], average_loss:0.4899, validation_loss:0.4838
# Epoch [71/200], average_loss:0.4890, validation_loss:0.4830
# Epoch [72/200], average_loss:0.4875, validation_loss:0.4817
# Epoch [73/200], average_loss:0.4868, validation_loss:0.4807
# Epoch [74/200], average_loss:0.4862, validation_loss:0.4801
# Epoch [75/200], average_loss:0.4850, validation_loss:0.4798
# Epoch [76/200], average_loss:0.4844, validation_loss:0.4785
# Epoch [77/200], average_loss:0.4842, validation_loss:0.4780
# Epoch [78/200], average_loss:0.4831, validation_loss:0.4798
# Epoch [79/200], average_loss:0.4829, validation_loss:0.4770
# Epoch [80/200], average_loss:0.4819, validation_loss:0.4757
# Epoch [81/200], average_loss:0.4810, validation_loss:0.4754
# Epoch [82/200], average_loss:0.4799, validation_loss:0.4748
# Epoch [83/200], average_loss:0.4798, validation_loss:0.4739
# Epoch [84/200], average_loss:0.4786, validation_loss:0.4731
# Epoch [85/200], average_loss:0.4784, validation_loss:0.4722
# Epoch [86/200], average_loss:0.4777, validation_loss:0.4715
# Epoch [87/200], average_loss:0.4774, validation_loss:0.4710
# Epoch [88/200], average_loss:0.4765, validation_loss:0.4711
# Epoch [89/200], average_loss:0.4757, validation_loss:0.4714
# Epoch [90/200], average_loss:0.4744, validation_loss:0.4695
# Epoch [91/200], average_loss:0.4739, validation_loss:0.4683
# Epoch [92/200], average_loss:0.4730, validation_loss:0.4677
# Epoch [93/200], average_loss:0.4736, validation_loss:0.4679
# Epoch [94/200], average_loss:0.4717, validation_loss:0.4688
# Epoch [95/200], average_loss:0.4725, validation_loss:0.4660
# Epoch [96/200], average_loss:0.4706, validation_loss:0.4661
# Epoch [97/200], average_loss:0.4704, validation_loss:0.4647
# Epoch [98/200], average_loss:0.4697, validation_loss:0.4643
# Epoch [99/200], average_loss:0.4695, validation_loss:0.4635
# Epoch [100/200], average_loss:0.4687, validation_loss:0.4634
# Epoch [101/200], average_loss:0.4677, validation_loss:0.4627
# Epoch [102/200], average_loss:0.4676, validation_loss:0.4617
# Epoch [103/200], average_loss:0.4671, validation_loss:0.4615
# Epoch [104/200], average_loss:0.4669, validation_loss:0.4607
# Epoch [105/200], average_loss:0.4653, validation_loss:0.4603
# Epoch [106/200], average_loss:0.4646, validation_loss:0.4600
# Epoch [107/200], average_loss:0.4650, validation_loss:0.4589
# Epoch [108/200], average_loss:0.4644, validation_loss:0.4584
# Epoch [109/200], average_loss:0.4631, validation_loss:0.4586
# Epoch [110/200], average_loss:0.4631, validation_loss:0.4574
# Epoch [111/200], average_loss:0.4626, validation_loss:0.4573
# Epoch [112/200], average_loss:0.4616, validation_loss:0.4561
# Epoch [113/200], average_loss:0.4621, validation_loss:0.4562
# Epoch [114/200], average_loss:0.4612, validation_loss:0.4552
# Epoch [115/200], average_loss:0.4607, validation_loss:0.4553
# Epoch [116/200], average_loss:0.4601, validation_loss:0.4543
# Epoch [117/200], average_loss:0.4603, validation_loss:0.4547
# Epoch [118/200], average_loss:0.4593, validation_loss:0.4532
# Epoch [119/200], average_loss:0.4590, validation_loss:0.4530
# Epoch [120/200], average_loss:0.4584, validation_loss:0.4534
# Epoch [121/200], average_loss:0.4577, validation_loss:0.4527
# Epoch [122/200], average_loss:0.4573, validation_loss:0.4524
# Epoch [123/200], average_loss:0.4572, validation_loss:0.4515
# Epoch [124/200], average_loss:0.4567, validation_loss:0.4506
# Epoch [125/200], average_loss:0.4561, validation_loss:0.4505
# Epoch [126/200], average_loss:0.4558, validation_loss:0.4497
# Epoch [127/200], average_loss:0.4555, validation_loss:0.4498
# Epoch [128/200], average_loss:0.4550, validation_loss:0.4491
# Epoch [129/200], average_loss:0.4552, validation_loss:0.4493
# Epoch [130/200], average_loss:0.4546, validation_loss:0.4502
# Epoch [131/200], average_loss:0.4548, validation_loss:0.4476
# Epoch [132/200], average_loss:0.4532, validation_loss:0.4473
# Epoch [133/200], average_loss:0.4535, validation_loss:0.4487
# Epoch [134/200], average_loss:0.4529, validation_loss:0.4469
# Epoch [135/200], average_loss:0.4524, validation_loss:0.4473
# Epoch [136/200], average_loss:0.4525, validation_loss:0.4471
# Epoch [137/200], average_loss:0.4520, validation_loss:0.4454
# Epoch [138/200], average_loss:0.4518, validation_loss:0.4460
# Epoch [139/200], average_loss:0.4512, validation_loss:0.4448
# Epoch [140/200], average_loss:0.4514, validation_loss:0.4451
# Epoch [141/200], average_loss:0.4508, validation_loss:0.4445
# Epoch [142/200], average_loss:0.4504, validation_loss:0.4442
# Epoch [143/200], average_loss:0.4502, validation_loss:0.4442
# Epoch [144/200], average_loss:0.4504, validation_loss:0.4438
# Epoch [145/200], average_loss:0.4492, validation_loss:0.4431
# Epoch [146/200], average_loss:0.4494, validation_loss:0.4427
# Epoch [147/200], average_loss:0.4494, validation_loss:0.4423
# Epoch [148/200], average_loss:0.4484, validation_loss:0.4426
# Epoch [149/200], average_loss:0.4492, validation_loss:0.4421
# Epoch [150/200], average_loss:0.4492, validation_loss:0.4417
# Epoch [151/200], average_loss:0.4475, validation_loss:0.4414
# Epoch [152/200], average_loss:0.4471, validation_loss:0.4415
# Epoch [153/200], average_loss:0.4478, validation_loss:0.4407
# Epoch [154/200], average_loss:0.4472, validation_loss:0.4409
# Epoch [155/200], average_loss:0.4467, validation_loss:0.4415
# Epoch [156/200], average_loss:0.4466, validation_loss:0.4403
# Epoch [157/200], average_loss:0.4459, validation_loss:0.4391
# Epoch [158/200], average_loss:0.4458, validation_loss:0.4388
# Epoch [159/200], average_loss:0.4454, validation_loss:0.4387
# Epoch [160/200], average_loss:0.4459, validation_loss:0.4408
# Epoch [161/200], average_loss:0.4453, validation_loss:0.4381
# Epoch [162/200], average_loss:0.4441, validation_loss:0.4381
# Epoch [163/200], average_loss:0.4443, validation_loss:0.4379
# Epoch [164/200], average_loss:0.4440, validation_loss:0.4370
# Epoch [165/200], average_loss:0.4432, validation_loss:0.4365
# Epoch [166/200], average_loss:0.4433, validation_loss:0.4365
# Epoch [167/200], average_loss:0.4432, validation_loss:0.4360
# Epoch [168/200], average_loss:0.4421, validation_loss:0.4361
# Epoch [169/200], average_loss:0.4426, validation_loss:0.4359
# Epoch [170/200], average_loss:0.4419, validation_loss:0.4354
# Epoch [171/200], average_loss:0.4415, validation_loss:0.4351
# Epoch [172/200], average_loss:0.4420, validation_loss:0.4346
# Epoch [173/200], average_loss:0.4416, validation_loss:0.4342
# Epoch [174/200], average_loss:0.4410, validation_loss:0.4340
# Epoch [175/200], average_loss:0.4402, validation_loss:0.4346
# Epoch [176/200], average_loss:0.4405, validation_loss:0.4335
# Epoch [177/200], average_loss:0.4401, validation_loss:0.4336
# Epoch [178/200], average_loss:0.4401, validation_loss:0.4337
# Epoch [179/200], average_loss:0.4397, validation_loss:0.4339
# Epoch [180/200], average_loss:0.4396, validation_loss:0.4327
# Epoch [181/200], average_loss:0.4388, validation_loss:0.4327
# Epoch [182/200], average_loss:0.4392, validation_loss:0.4317
# Epoch [183/200], average_loss:0.4384, validation_loss:0.4319
# Epoch [184/200], average_loss:0.4381, validation_loss:0.4315
# Epoch [185/200], average_loss:0.4386, validation_loss:0.4312
# Epoch [186/200], average_loss:0.4384, validation_loss:0.4308
# Epoch [187/200], average_loss:0.4372, validation_loss:0.4311
# Epoch [188/200], average_loss:0.4370, validation_loss:0.4305
# Epoch [189/200], average_loss:0.4370, validation_loss:0.4301
# Epoch [190/200], average_loss:0.4368, validation_loss:0.4315
# Epoch [191/200], average_loss:0.4364, validation_loss:0.4298
# Epoch [192/200], average_loss:0.4368, validation_loss:0.4320
# Epoch [193/200], average_loss:0.4367, validation_loss:0.4296
# Epoch [194/200], average_loss:0.4362, validation_loss:0.4301
# Epoch [195/200], average_loss:0.4361, validation_loss:0.4306
# Epoch [196/200], average_loss:0.4358, validation_loss:0.4286
# Epoch [197/200], average_loss:0.4355, validation_loss:0.4283
# Epoch [198/200], average_loss:0.4346, validation_loss:0.4286
# Epoch [199/200], average_loss:0.4346, validation_loss:0.4279
# Epoch [200/200], average_loss:0.4349, validation_loss:0.4275

# %%
plot_loss(m4)

# %% [markdown]
# ## Batch size 100 + learning rate 1e-3 and 1e-4 + Sigmoid

# %%
train_loader = torch.utils.data.DataLoader(dataset = train, batch_size=100, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset = test, batch_size=100, shuffle=True)

# %%
model5 = DNN(n_layers=2, neurons=[160, 128, 64], output_dim=4, activation=nn.Sigmoid(), dropout=False)

# %%
optimizer = torch.optim.Adam(model5.parameters(), lr=1e-3)

# %%
m5 = Trainer(
        model=model5,
        optimizer=optimizer, # it is scheduler 
        loss_function=nn.CrossEntropyLoss(),
        scheduler=torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[50], gamma=0.1),
        verbose=True
        )
# Out:
# cuda:0

# %%
lh = m5(epochs=200, train_loader=train_loader, validation_loader=test_loader)
# Out:
# Epoch [1/200], average_loss:0.7231, validation_loss:0.5628
# Epoch [2/200], average_loss:0.5470, validation_loss:0.5200
# Epoch [3/200], average_loss:0.5190, validation_loss:0.5074
# Epoch [4/200], average_loss:0.5018, validation_loss:0.4859
# Epoch [5/200], average_loss:0.4892, validation_loss:0.4843
# Epoch [6/200], average_loss:0.4773, validation_loss:0.4621
# Epoch [7/200], average_loss:0.4693, validation_loss:0.4626
# Epoch [8/200], average_loss:0.4630, validation_loss:0.4623
# Epoch [9/200], average_loss:0.4575, validation_loss:0.4478
# Epoch [10/200], average_loss:0.4535, validation_loss:0.4417
# Epoch [11/200], average_loss:0.4507, validation_loss:0.4438
# Epoch [12/200], average_loss:0.4474, validation_loss:0.4449
# Epoch [13/200], average_loss:0.4427, validation_loss:0.4402
# Epoch [14/200], average_loss:0.4416, validation_loss:0.4258
# Epoch [15/200], average_loss:0.4388, validation_loss:0.4280
# Epoch [16/200], average_loss:0.4337, validation_loss:0.4431
# Epoch [17/200], average_loss:0.4318, validation_loss:0.4246
# Epoch [18/200], average_loss:0.4287, validation_loss:0.4171
# Epoch [19/200], average_loss:0.4251, validation_loss:0.4223
# Epoch [20/200], average_loss:0.4237, validation_loss:0.4207
# Epoch [21/200], average_loss:0.4209, validation_loss:0.4070
# Epoch [22/200], average_loss:0.4191, validation_loss:0.4078
# Epoch [23/200], average_loss:0.4163, validation_loss:0.4043
# Epoch [24/200], average_loss:0.4140, validation_loss:0.4121
# Epoch [25/200], average_loss:0.4121, validation_loss:0.4116
# Epoch [26/200], average_loss:0.4107, validation_loss:0.4036
# Epoch [27/200], average_loss:0.4100, validation_loss:0.4042
# Epoch [28/200], average_loss:0.4061, validation_loss:0.3975
# Epoch [29/200], average_loss:0.4052, validation_loss:0.4029
# Epoch [30/200], average_loss:0.4041, validation_loss:0.4055

# %%
plot_loss(m5)

# %% [markdown]
# ## Batch size 300 + learning rate 1e-3 and 1e-4 + Sigmoid

# %%
train_loader = torch.utils.data.DataLoader(dataset = train, batch_size=300, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset = test, batch_size=300, shuffle=True)

# %%
model6 = DNN(n_layers=2, neurons=[160, 128, 64], output_dim=4, activation=nn.Sigmoid(), dropout=False)

# %%
optimizer = torch.optim.Adam(model6.parameters(), lr=1e-3)

# %%
m6 = Trainer(
        model=model6,
        optimizer=optimizer,
        loss_function=nn.CrossEntropyLoss(),
        scheduler=MultiStepLR(optimizer, milestones=[50], gamma=0.1),
        verbose=True
        )

# %%
lh = m6(epochs=200, train_loader=train_loader, validation_loader=test_loader)

# %%
plot_loss(m6)

# %% [markdown]
# ## Batch size 300 + learning rate 1e-2, 1e-3 and 1e-4 + Sigmoid

# %%
train_loader = torch.utils.data.DataLoader(dataset = train, batch_size=300, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset = test, batch_size=300, shuffle=True)

# %%
model7 = DNN(n_layers=2, neurons=[160, 128, 64], output_dim=4, activation=nn.Sigmoid(), dropout=False)

# %%
optimizer = torch.optim.Adam(model7.parameters(), lr=1e-2)

# %%
m7 = Trainer(
        model=model7,
        optimizer=optimizer,
        loss_function=nn.CrossEntropyLoss(),
        scheduler=MultiStepLR(optimizer, milestones=[50,100], gamma=0.1),
        verbose=True
        )

# %%
lh = m7(epochs=200, train_loader=train_loader, validation_loader=test_loader)

# %%
plot_loss(m7)
