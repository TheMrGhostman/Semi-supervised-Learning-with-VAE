# %%
#!git clone https://github.com/TheMrGhostman/Semi-supervised-Learning-with-VAE

# %%
#!pip install pyro-ppl

# %%
import os
import time

import numpy as np
import torch

import torch.nn as nn
import torch.nn.functional as F

import pyro
import pyro.distributions as dist
import pyro.contrib.examples.util  # patches torchvision

from pyro.infer import SVI, JitTrace_ELBO, JitTraceEnum_ELBO, Trace_ELBO, TraceEnum_ELBO, config_enumerate
from pyro.optim import Adam

import matplotlib.pyplot as plt

# %%
#os.chdir("Semi-supervised-Learning-with-VAE/")

# %%
from utils.datasets import SupervisedDataset
from utils.utils import One_Hot

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler, StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score

from utils.layers import Reshape, Flatten
import utils.datasets as d

# %%
class VariationalLayer(nn.Module):
    """
    Variational Layer with reparametrization trick. 
    It's used as bottleneck of Variational AutoEncoder ie. output of encoder.

    "Linear layer for variational inference with reparametrization trick"
    """
    def __init__(self, in_features, out_features, bias=True):
        """	
        : param in_features: 		Number of input features (number of neurons on input)
        : param out_features:		Number of output features (number of neurons on output)
        : param bias:				Include bias - True/False
        """
        super(VariationalLayer, self).__init__()
        self.mu = nn.Linear(in_features=in_features, out_features=out_features, bias=bias)
        self.rho = nn.Linear(in_features=in_features, out_features=out_features, bias=bias)
        self.softplus = nn.Softplus()

    def forward(self, x_in):
        mu = self.mu(x_in)
        sigma = self.softplus(self.rho(x_in))
        return mu, sigma

# %%
class ConvTransposeDecoderOutput(nn.Module):
    def __init__(self, in_channels, in_features, out_features, kernel_size, stride=1, padding=0, bias=True):
        super(ConvTransposeDecoderOutput, self).__init__()
        self.mu = nn.ConvTranspose1d(
                in_channels=in_channels, 
                out_channels=1, 
                kernel_size=kernel_size, 
                stride=stride, 
                padding=padding
            )
        self.rho = nn.Linear(in_features=in_features, out_features=1, bias=bias)
        self.flatten = Flatten(out_features=in_features)
        self.flatten_mu = Flatten(out_features=out_features)
        self.softplus = nn.Softplus()

    def forward(self, x_in):
        """
        x must be shape ... (-1, in_channels, size)
        """
        mu = self.mu(x_in)
        x = self.flatten(x_in)
        sigma = self.softplus(self.rho(x))
        return self.flatten_mu(mu), sigma

# %%
class ConvTransposeDecoderOutput2(nn.Module):
    def __init__(self, in_channels, out_features, kernel_size, stride=1, padding=0, bias=True):
        super(ConvTransposeDecoderOutput2, self).__init__()
        self.mu = nn.ConvTranspose1d(
                in_channels=in_channels, 
                out_channels=1, 
                kernel_size=kernel_size, 
                stride=stride, 
                padding=padding
            )
        self.flatten_mu = Flatten(out_features=out_features)

    def forward(self, x_in):
        """
        x must be shape ... (-1, in_channels, size)
        """
        mu = self.mu(x_in)
        return self.flatten_mu(mu)

# %%
class Encoder(nn.Module):
    def __init__(self):
        super(Encoder, self).__init__()
        self.first_part =  nn.Sequential(
                Reshape(out_shape=(1, 160)),
                nn.Conv1d(in_channels=1, out_channels=16, kernel_size=6, stride=2, padding=0, bias=False), # n*1*160 -> n*16*78
                nn.PReLU(),
                nn.Conv1d(in_channels=16, out_channels=32, kernel_size=4, stride=2, bias=False),#n*16*78->n*32*38
                nn.BatchNorm1d(num_features=32),
                nn.PReLU(),
                nn.Conv1d(in_channels=32, out_channels=64, kernel_size=4, stride=2, bias=False),#n*32*38->n*64*18
                nn.BatchNorm1d(num_features=64),
                nn.PReLU(),
                Flatten(out_features=64*18))
        self.fc = nn.Linear(in_features=64*18+4, out_features=256)
        self.act = nn.PReLU()
        self.out = VariationalLayer(in_features=256, out_features=15)
        
    def forward(self, x,y):
        z = self.first_part(x)
        z = torch.cat([z,y], axis=1)
        z = self.act(self.fc(z))
        return self.out(z)

# %%
decoder = nn.Sequential(
    nn.Linear(in_features=15+4, out_features=256),
    nn.PReLU(),
    nn.Linear(in_features=256, out_features=64*18),
    Reshape(out_shape=(64,18)),
    nn.BatchNorm1d(num_features=64),
    nn.PReLU(),
    nn.ConvTranspose1d(in_channels=64, out_channels=32, kernel_size=4, stride=2, padding=0),
    nn.BatchNorm1d(num_features=32),
    nn.PReLU(),
    nn.ConvTranspose1d(in_channels=32, out_channels=16, kernel_size=4, stride=2, padding=0),
    #nn.BatchNorm1d(num_features=16),
    nn.PReLU(),
    ConvTransposeDecoderOutput(
        in_channels=16,
        in_features=16*78,
        out_features=160, 
        kernel_size=6, 
        stride=2
        )
    )

# %%
clf = nn.Sequential(
    Reshape(out_shape=(1, 160)),
    nn.Conv1d(in_channels=1, out_channels=16, kernel_size=6, stride=2, padding=0, bias=False), # n*1*160 -> n*16*78
    nn.PReLU(),
    nn.Conv1d(in_channels=16, out_channels=32, kernel_size=4, stride=2, bias=False),#n*16*78->n*32*38
    nn.BatchNorm1d(num_features=32),
    nn.PReLU(),
    nn.Conv1d(in_channels=32, out_channels=64, kernel_size=4, stride=2, bias=False),#n*32*38->n*64*18
    nn.BatchNorm1d(num_features=64),
    nn.PReLU(),
    Flatten(out_features=64*18),
    nn.Linear(in_features=64*18, out_features=256),
    nn.PReLU(),
    nn.Linear(in_features=256, out_features=4),
    nn.Softmax(dim=1)
    )

# %%
class SSVAE(nn.Module):
    """
    This class encapsulates the parameters (neural networks) and models & guides needed to train a
    semi-supervised variational auto-encoder on the MNIST image dataset
    :param output_size: size of the tensor representing the class label (10 for MNIST since
                        we represent the class labels as a one-hot vector with 10 components)
    :param input_size: size of the tensor representing the image (28*28 = 784 for our MNIST dataset
                       since we flatten the images and scale the pixels to be in [0,1])
    :param z_dim: size of the tensor representing the latent random variable z
                  (handwriting style for our MNIST dataset)
    :param hidden_layers: a tuple (or list) of MLP layers to be used in the neural networks
                          representing the parameters of the distributions in our model
    :param use_cuda: use GPUs for faster training
    :param aux_loss_multiplier: the multiplier to use with the auxiliary loss
    """
    def __init__(self, config_enum=None, use_cuda=False, aux_loss_multiplier=None):

        super().__init__()

        # initialize the class with all arguments provided to the constructor
        self.output_size = 4
        self.z_dim = 15
        self.allow_broadcast = config_enum == 'parallel'
        self.use_cuda = use_cuda
        self.aux_loss_multiplier = aux_loss_multiplier

        # define and instantiate the neural networks representing
        # the paramters of various distributions in the model
        self.setup_networks()

    def setup_networks(self):

        self.encoder_y = clf

        self.encoder_z = Encoder()

        self.decoder = decoder

        if self.use_cuda:
            self.cuda()

    def model(self, xs, ys=None):
        """
        The model corresponds to the following generative process:
        p(z) = normal(0,I)              # handwriting style (latent)
        p(y|x) = categorical(I/10.)     # which digit (semi-supervised)
        p(x|y,z) = bernoulli(loc(y,z))   # an image
        loc is given by a neural network  `decoder`
        :param xs: a batch of scaled vectors of pixels from an image
        :param ys: (optional) a batch of the class labels i.e.
                   the digit corresponding to the image(s)
        :return: None
        """
        # register this pytorch module and all of its sub-modules with pyro
        pyro.module("ss_vae", self)

        batch_size = xs.size(0)
        options = dict(dtype=xs.dtype, device=xs.device)
        with pyro.plate("data"):

            # sample the handwriting style from the constant prior distribution
            prior_loc = torch.zeros(batch_size, self.z_dim, **options)
            prior_scale = torch.ones(batch_size, self.z_dim, **options)
            zs = pyro.sample("z", dist.Normal(prior_loc, prior_scale).to_event(1))

            # if the label y (which digit to write) is supervised, sample from the
            # constant prior, otherwise, observe the value (i.e. score it against the constant prior)
            alpha_prior = torch.ones(batch_size, self.output_size, **options) / (1.0 * self.output_size)
            ys = pyro.sample("y", dist.OneHotCategorical(alpha_prior), obs=ys)

            # finally, score the image (x) using the handwriting style (z) and
            # the class label y (which digit to write) against the
            # parametrized distribution p(x|y,z) = bernoulli(decoder(y,z))
            # where `decoder` is a neural network
            mu, sigma = self.decoder(torch.cat([zs, ys], axis=1))
            #mu = self.decoder(torch.cat([zs, ys], axis=1))
            #pyro.sample("x", dist.Normal(mu,torch.ones((mu.shape[0],1)).cuda()).to_event(1), obs=xs)
            pyro.sample("x", dist.Normal(mu,sigma).to_event(1), obs=xs)
            # return the loc so we can visualize it later
            return mu

    def guide(self, xs, ys=None):
        """
        The guide corresponds to the following:
        q(y|x) = categorical(alpha(x))              # infer digit from an image
        q(z|x,y) = normal(loc(x,y),scale(x,y))       # infer handwriting style from an image and the digit
        loc, scale are given by a neural network `encoder_z`
        alpha is given by a neural network `encoder_y`
        :param xs: a batch of scaled vectors of pixels from an image
        :param ys: (optional) a batch of the class labels i.e.
                   the digit corresponding to the image(s)
        :return: None
        """
        # inform Pyro that the variables in the batch of xs, ys are conditionally independent
        with pyro.plate("data"):

            # if the class label (the digit) is not supervised, sample
            # (and score) the digit with the variational distribution
            # q(y|x) = categorical(alpha(x))
            if ys is None:
                alpha = self.encoder_y(xs)
                ys = pyro.sample("y", dist.OneHotCategorical(alpha))

            # sample (and score) the latent handwriting-style with the variational
            # distribution q(z|x,y) = normal(loc(x,y),scale(x,y))
            loc, scale = self.encoder_z(xs, ys)
            pyro.sample("z", dist.Normal(loc, scale).to_event(1))

    def classifier(self, xs):
        """
        classify an image (or a batch of images)
        :param xs: a batch of scaled vectors of pixels from an image
        :return: a batch of the corresponding class labels (as one-hots)
        """
        # use the trained model q(y|x) = categorical(alpha(x))
        # compute all class probabilities for the image(s)
        alpha = self.encoder_y(xs)

        # get the index (digit) that corresponds to
        # the maximum predicted class probability
        res, ind = torch.topk(alpha, 1)

        # convert the digit(s) to one-hot tensor(s)
        ys = torch.zeros_like(alpha).scatter_(1, ind, 1.0)
        return ys

    def model_classify(self, xs, ys=None):
        """
        this model is used to add an auxiliary (supervised) loss as described in the
        Kingma et al., "Semi-Supervised Learning with Deep Generative Models".
        """
        # register all pytorch (sub)modules with pyro
        pyro.module("ss_vae", self)

        # inform Pyro that the variables in the batch of xs, ys are conditionally independent
        with pyro.plate("data"):
            # this here is the extra term to yield an auxiliary loss that we do gradient descent on
            if ys is not None:
                alpha = self.encoder_y.forward(xs)
                with pyro.poutine.scale(scale=self.aux_loss_multiplier):
                    pyro.sample("y_aux", dist.OneHotCategorical(alpha), obs=ys)

    def guide_classify(self, xs, ys=None):
        """
        dummy guide function to accompany model_classify in inference
        """
        pass

# %%
def get_accuracy(data_loader, clf):
    """
        clf ... ssvae.classifier()
    """
    dataloader_len = len(data_loader)
    acc = 0
    with torch.no_grad():
        for (xs, ys) in data_loader:
            xs = xs.cuda()
            pred = clf(xs)
            acc += accuracy_score(np.argmax(pred.cpu().detach().numpy(), axis=1) , np.argmax(ys.numpy(),axis=1))
    return acc/dataloader_len

# %%
def run_inference_for_epoch(data_loaders, losses):
    """
        thanks to random sampler supervised and unsupervised datasets have the same length

        two losses -> [ ELBO , -E(q(y|x)) ]
    """
    num_losses = len(losses) 

    epoch_losses_sup = [0.] * num_losses
    epoch_losses_unsup = [0.] * num_losses

    sup_iter = iter(data_loaders["sup"])
    unsup_iter = iter(data_loaders["unsup"])
    
    #model.train()
    for batch_idx  in range(len(data_loaders["unsup"])):
        
        # supervised flow
        (xs, ys) = next(sup_iter)
        for loss_id in range(num_losses):
            # evaluating (tracing) losses and optimizer step 
            new_loss = losses[loss_id].step(xs.cuda(), ys.cuda())
            # saving losses 
            epoch_losses_sup[loss_id] += new_loss
        

        # unsupervised flow
        xs = next(unsup_iter)
        for loss_id in range(num_losses):
            # evaluating (tracing) losses and optimizer step 
            new_loss = losses[loss_id].step(xs.cuda())
            # saving losses
            epoch_losses_unsup[loss_id] += new_loss

            
    return epoch_losses_sup, epoch_losses_unsup

# %% [markdown]
# # Get Data

# %%
X_s = np.vstack((np.load("data/sequenced_data_for_VAE_length-160_stride-10_pt1.npy"),
               np.load("data/sequenced_data_for_VAE_length-160_stride-10_pt2.npy")))
y_s = np.load("data/sequenced_data_for_VAE_length-160_stride-10_targets.npy")

# %%
X_u = np.vstack((np.load("data/unlabeled_sequences_part_1.npy"), np.load("data/unlabeled_sequences_part_2.npy")))

# %%
print(X_s.shape)
print(X_u.shape)
# Out:
# (83680, 160)
# (97400, 160)

# %%
X_train, X_test, y_train, y_test = train_test_split(np.array(X_s), np.array(y_s), test_size=0.2, random_state=666)

# %%
scaler = RobustScaler()
scaler.fit(np.vstack((np.array(X_s),np.array(X_u))))

X_sup= scaler.transform(X_train)
X_unsup = scaler.transform(np.array(X_u))
X_test = scaler.transform(X_test)

# %% [markdown]
# # Defining model and inference

# %%
ss_vae = SSVAE(config_enum="parallel", use_cuda=True, aux_loss_multiplier=True)

# %%
adam_params = {"lr": 0.0001}
optimizer = Adam(adam_params)

# %% [markdown]
# ## ELBO of main loss $\mathcal{J} = \sum_{sup} \mathcal{L}(\vec{x},y) + \sum_{unsup} \mathcal{U}(\vec{x})$

# %%
guide = config_enumerate(ss_vae.guide, "sequential", expand=True) #config_enumerate(ss_vae.guide, "parallel", expand=True)
elbo = TraceEnum_ELBO(max_plate_nesting=1) #JitTraceEnum_ELBO
loss_basic = SVI(ss_vae.model, guide, optimizer, loss=elbo)

# %%
losses = [loss_basic]

# %% [markdown]
# ## adding auxillary loss $\mathbb{E}_{sup}[- \log q(y|\vec{x})]$

# %%
elbo = Trace_ELBO()
loss_aux = SVI(ss_vae.model_classify, ss_vae.guide_classify, optimizer, loss=elbo)
losses.append(loss_aux)

# %% [markdown]
# # Training

# %%
sup_num = X_unsup.shape[0]
unsup_num = X_unsup.shape[0]
periodic_interval_batches = 1
best_valid_acc, corresponding_test_acc = 0.0, 0.0

# %%
batch_size = 512

# %%
sup = d.SupervisedDataset(X_sup, One_Hot(4)(y_train))
test = d.SupervisedDataset(X_test, One_Hot(4)(y_test))

# %%
data_loaders = {}
data_loaders["sup"] = torch.utils.data.DataLoader(
                            dataset=sup,
                            batch_size=batch_size, 
                            shuffle=False, 
                            sampler=torch.utils.data.RandomSampler(
                                sup, 
                                replacement=True,
                                num_samples=X_unsup.shape[0]
                                )
                            )
data_loaders["unsup"] = torch.utils.data.DataLoader(
                            dataset=torch.tensor(X_unsup).float(), 
                            batch_size=batch_size, 
                            shuffle=False, 
                            sampler=torch.utils.data.RandomSampler(
                                X_unsup, 
                                replacement=False
                                )
)
#data_loaders["valid"] = torch.utils.data.DataLoader(SupervisedDataset(X_train[-5000:].view(-1, 1,28,28), y_train[-5000:]), 
#                                                  batch_size=batch_size)
data_loaders["test"] = torch.utils.data.DataLoader(test, batch_size=batch_size)

# %%
sup_loss, unsup_loss, clf_loss, test_acc = [],[],[],[]

# %%
n_epochs = 50

# %%
for i in range(0,n_epochs): # 10 epochs for start
    start = time.time()
    epoch_sup_loss, epoch_unsup_loss = run_inference_for_epoch(data_loaders, losses)

    sup_loss.append(epoch_sup_loss[0]/sup_num)
    clf_loss.append(epoch_sup_loss[1]/sup_num)
    unsup_loss.append(epoch_unsup_loss[0]/unsup_num)

    test_accuracy = get_accuracy(data_loaders["test"], ss_vae.encoder_y)
    test_acc.append(test_accuracy)

    
    print("Epoch [{}/{}], time {:.2f}s, sup_loss:{:.4f}, sup_clf_loss:{:.4f}, unsup_loss:{:.4f}, test_accuracy:{:.4f}"\
          .format(i+1, n_epochs, time.time()-start, sup_loss[-1], clf_loss[-1], unsup_loss[-1], test_accuracy))
# Out:
# Epoch [1/50], time 110.07s, sup_loss:0.9760, sup_clf_loss:1.8327, unsup_loss:-40.0442, test_accuracy:0.2388
# Epoch [2/50], time 109.09s, sup_loss:-99.8655, sup_clf_loss:1.7320, unsup_loss:-127.6046, test_accuracy:0.4364
# Epoch [3/50], time 109.56s, sup_loss:-127.0159, sup_clf_loss:2.7715, unsup_loss:-151.3996, test_accuracy:0.2927
# Epoch [4/50], time 108.70s, sup_loss:-139.8865, sup_clf_loss:1.2343, unsup_loss:-166.1194, test_accuracy:0.5211
# Epoch [5/50], time 107.71s, sup_loss:-143.9562, sup_clf_loss:1.9152, unsup_loss:-167.9128, test_accuracy:0.4197
# Epoch [6/50], time 106.28s, sup_loss:-152.6875, sup_clf_loss:2.0586, unsup_loss:-175.6896, test_accuracy:0.4153
# Epoch [7/50], time 106.67s, sup_loss:-159.5585, sup_clf_loss:1.4608, unsup_loss:-184.2994, test_accuracy:0.6739
# Epoch [8/50], time 106.70s, sup_loss:-161.2759, sup_clf_loss:1.4019, unsup_loss:-187.8771, test_accuracy:0.7202
# Epoch [9/50], time 106.76s, sup_loss:-168.8158, sup_clf_loss:2.2395, unsup_loss:-191.7797, test_accuracy:0.5635
# Epoch [10/50], time 106.35s, sup_loss:-167.1196, sup_clf_loss:2.0179, unsup_loss:-194.2478, test_accuracy:0.3537
# Epoch [11/50], time 105.30s, sup_loss:-170.8842, sup_clf_loss:2.0579, unsup_loss:-194.0874, test_accuracy:0.2815
# Epoch [12/50], time 104.99s, sup_loss:-176.4266, sup_clf_loss:1.6343, unsup_loss:-200.8139, test_accuracy:0.7105
# Epoch [13/50], time 105.44s, sup_loss:-176.1280, sup_clf_loss:0.8481, unsup_loss:-203.3739, test_accuracy:0.7639
# Epoch [14/50], time 108.49s, sup_loss:-179.7888, sup_clf_loss:1.3180, unsup_loss:-205.3227, test_accuracy:0.4241
# Epoch [15/50], time 107.76s, sup_loss:-181.4238, sup_clf_loss:1.2159, unsup_loss:-206.6314, test_accuracy:0.7436
# Epoch [16/50], time 107.42s, sup_loss:-182.3173, sup_clf_loss:1.3244, unsup_loss:-207.9410, test_accuracy:0.6621
# Epoch [17/50], time 106.59s, sup_loss:-183.7047, sup_clf_loss:0.8927, unsup_loss:-208.2861, test_accuracy:0.3952
# Epoch [18/50], time 107.50s, sup_loss:-187.1695, sup_clf_loss:0.9151, unsup_loss:-211.1710, test_accuracy:0.7702
# Epoch [19/50], time 106.66s, sup_loss:-189.2567, sup_clf_loss:0.6778, unsup_loss:-213.5165, test_accuracy:0.5875
# Epoch [20/50], time 106.46s, sup_loss:-188.9235, sup_clf_loss:1.0768, unsup_loss:-213.4658, test_accuracy:0.6848
# Epoch [21/50], time 106.83s, sup_loss:-190.2237, sup_clf_loss:1.6413, unsup_loss:-217.7555, test_accuracy:0.7679
# Epoch [22/50], time 107.07s, sup_loss:-194.8912, sup_clf_loss:1.3088, unsup_loss:-219.8095, test_accuracy:0.2850
# Epoch [23/50], time 107.04s, sup_loss:-198.0708, sup_clf_loss:1.8538, unsup_loss:-218.2587, test_accuracy:0.7389
# Epoch [24/50], time 106.74s, sup_loss:-195.3690, sup_clf_loss:1.3143, unsup_loss:-222.5306, test_accuracy:0.6924
# Epoch [25/50], time 106.71s, sup_loss:-197.9205, sup_clf_loss:0.5373, unsup_loss:-220.5952, test_accuracy:0.7887
# Epoch [26/50], time 106.58s, sup_loss:-197.9483, sup_clf_loss:0.5190, unsup_loss:-222.0345, test_accuracy:0.8096
# Epoch [27/50], time 106.60s, sup_loss:-199.7303, sup_clf_loss:0.5225, unsup_loss:-225.1484, test_accuracy:0.8097
# Epoch [28/50], time 108.01s, sup_loss:-198.8693, sup_clf_loss:1.5513, unsup_loss:-224.4831, test_accuracy:0.6362
# Epoch [29/50], time 107.24s, sup_loss:-202.3945, sup_clf_loss:0.5692, unsup_loss:-225.3537, test_accuracy:0.8150
# Epoch [30/50], time 107.42s, sup_loss:-200.0886, sup_clf_loss:0.7099, unsup_loss:-227.8511, test_accuracy:0.6596
# Epoch [31/50], time 107.12s, sup_loss:-199.8344, sup_clf_loss:0.6268, unsup_loss:-225.0580, test_accuracy:0.7782
# Epoch [32/50], time 106.99s, sup_loss:-202.6527, sup_clf_loss:1.1569, unsup_loss:-228.0285, test_accuracy:0.3292
# Epoch [33/50], time 106.77s, sup_loss:-201.6686, sup_clf_loss:0.8063, unsup_loss:-226.6709, test_accuracy:0.8090
# Epoch [34/50], time 106.19s, sup_loss:-208.2848, sup_clf_loss:0.4992, unsup_loss:-232.0747, test_accuracy:0.8043
# Epoch [35/50], time 107.12s, sup_loss:-202.1568, sup_clf_loss:1.2813, unsup_loss:-228.2194, test_accuracy:0.8106
# Epoch [36/50], time 106.67s, sup_loss:-202.5443, sup_clf_loss:0.7312, unsup_loss:-229.2221, test_accuracy:0.8223
# Epoch [37/50], time 106.55s, sup_loss:-204.8995, sup_clf_loss:0.5240, unsup_loss:-231.2680, test_accuracy:0.8065
# Epoch [38/50], time 107.14s, sup_loss:-206.0711, sup_clf_loss:0.5128, unsup_loss:-231.2484, test_accuracy:0.8400
# Epoch [39/50], time 106.75s, sup_loss:-207.5583, sup_clf_loss:1.1672, unsup_loss:-230.4675, test_accuracy:0.6158
# Epoch [40/50], time 106.70s, sup_loss:-207.2783, sup_clf_loss:0.4914, unsup_loss:-232.0486, test_accuracy:0.8139
# Epoch [41/50], time 106.64s, sup_loss:-207.9989, sup_clf_loss:0.4836, unsup_loss:-232.4176, test_accuracy:0.7914
# Epoch [42/50], time 106.69s, sup_loss:-206.7734, sup_clf_loss:1.4706, unsup_loss:-234.0091, test_accuracy:0.5724
# Epoch [43/50], time 106.47s, sup_loss:-208.6855, sup_clf_loss:0.9868, unsup_loss:-233.6416, test_accuracy:0.7909
# Epoch [44/50], time 106.47s, sup_loss:-209.5093, sup_clf_loss:0.4846, unsup_loss:-234.1701, test_accuracy:0.8400
# Epoch [45/50], time 105.23s, sup_loss:-209.1023, sup_clf_loss:0.4062, unsup_loss:-233.8046, test_accuracy:0.8375
# Epoch [46/50], time 104.35s, sup_loss:-208.6077, sup_clf_loss:1.4169, unsup_loss:-234.4524, test_accuracy:0.8064
# Epoch [47/50], time 104.80s, sup_loss:-213.2961, sup_clf_loss:0.4574, unsup_loss:-236.5337, test_accuracy:0.8413
# Epoch [48/50], time 103.97s, sup_loss:-211.5335, sup_clf_loss:1.1164, unsup_loss:-232.1750, test_accuracy:0.8048
# Epoch [49/50], time 105.06s, sup_loss:-210.9950, sup_clf_loss:0.5217, unsup_loss:-236.0238, test_accuracy:0.8455
# Epoch [50/50], time 105.93s, sup_loss:-210.6843, sup_clf_loss:0.4002, unsup_loss:-237.5454, test_accuracy:0.8342

# %%
for i in range(50,100): # 10 epochs for start
    start = time.time()
    epoch_sup_loss, epoch_unsup_loss = run_inference_for_epoch(data_loaders, losses)

    sup_loss.append(epoch_sup_loss[0]/sup_num)
    clf_loss.append(epoch_sup_loss[1]/sup_num)
    unsup_loss.append(epoch_unsup_loss[0]/unsup_num)

    test_accuracy = get_accuracy(data_loaders["test"], ss_vae.encoder_y)
    test_acc.append(test_accuracy)

    
    print("Epoch [{}/{}], time {:.2f}s, sup_loss:{:.4f}, sup_clf_loss:{:.4f}, unsup_loss:{:.4f}, test_accuracy:{:.4f}"\
          .format(i+1, 100, time.time()-start, sup_loss[-1], clf_loss[-1], unsup_loss[-1], test_accuracy))
# Out:
# Epoch [51/100], time 106.65s, sup_loss:-211.8394, sup_clf_loss:0.3715, unsup_loss:-234.8603, test_accuracy:0.8426
# Epoch [52/100], time 107.53s, sup_loss:-211.9300, sup_clf_loss:0.3901, unsup_loss:-237.0338, test_accuracy:0.8651
# Epoch [53/100], time 108.14s, sup_loss:-210.8224, sup_clf_loss:0.6108, unsup_loss:-236.3163, test_accuracy:0.8339
# Epoch [54/100], time 107.20s, sup_loss:-213.2407, sup_clf_loss:0.4009, unsup_loss:-239.6725, test_accuracy:0.8551
# Epoch [55/100], time 109.41s, sup_loss:-213.2075, sup_clf_loss:0.3542, unsup_loss:-238.8001, test_accuracy:0.8573
# Epoch [56/100], time 108.79s, sup_loss:-212.7138, sup_clf_loss:0.3481, unsup_loss:-238.5360, test_accuracy:0.8657
# Epoch [57/100], time 106.27s, sup_loss:-214.3219, sup_clf_loss:0.5109, unsup_loss:-237.3693, test_accuracy:0.7732
# Epoch [58/100], time 108.17s, sup_loss:-213.5756, sup_clf_loss:0.5437, unsup_loss:-238.8989, test_accuracy:0.8440
# Epoch [59/100], time 109.43s, sup_loss:-210.0242, sup_clf_loss:0.3728, unsup_loss:-239.2682, test_accuracy:0.8584
# Epoch [60/100], time 108.17s, sup_loss:-213.6704, sup_clf_loss:0.5004, unsup_loss:-239.9786, test_accuracy:0.8470
# Epoch [61/100], time 109.32s, sup_loss:-216.0082, sup_clf_loss:0.3537, unsup_loss:-237.6341, test_accuracy:0.8737
# Epoch [62/100], time 108.37s, sup_loss:-213.4482, sup_clf_loss:0.3425, unsup_loss:-238.3536, test_accuracy:0.8740
# Epoch [63/100], time 108.36s, sup_loss:-214.4005, sup_clf_loss:1.0524, unsup_loss:-240.6231, test_accuracy:0.8631
# Epoch [64/100], time 107.98s, sup_loss:-217.3493, sup_clf_loss:0.3415, unsup_loss:-241.2452, test_accuracy:0.8600
# Epoch [65/100], time 108.66s, sup_loss:-216.4876, sup_clf_loss:0.7177, unsup_loss:-239.8472, test_accuracy:0.8561
# Epoch [66/100], time 107.24s, sup_loss:-218.0840, sup_clf_loss:0.3425, unsup_loss:-241.2653, test_accuracy:0.8577
# Epoch [67/100], time 107.66s, sup_loss:-215.2866, sup_clf_loss:0.3300, unsup_loss:-240.4765, test_accuracy:0.8625
# Epoch [68/100], time 107.76s, sup_loss:-217.0011, sup_clf_loss:0.5853, unsup_loss:-241.5609, test_accuracy:0.8667
# Epoch [69/100], time 107.36s, sup_loss:-215.9524, sup_clf_loss:0.3474, unsup_loss:-239.5875, test_accuracy:0.8827
# Epoch [70/100], time 107.90s, sup_loss:-217.8497, sup_clf_loss:0.3269, unsup_loss:-241.8092, test_accuracy:0.8497
# Epoch [71/100], time 107.38s, sup_loss:-218.1742, sup_clf_loss:0.3147, unsup_loss:-238.5534, test_accuracy:0.8867
# Epoch [72/100], time 108.56s, sup_loss:-215.1717, sup_clf_loss:0.3315, unsup_loss:-239.6874, test_accuracy:0.8755
# Epoch [73/100], time 109.26s, sup_loss:-216.5012, sup_clf_loss:0.6933, unsup_loss:-240.2773, test_accuracy:0.5970
# Epoch [74/100], time 110.69s, sup_loss:-218.5679, sup_clf_loss:0.5465, unsup_loss:-242.8533, test_accuracy:0.6524
# Epoch [75/100], time 110.17s, sup_loss:-217.9518, sup_clf_loss:0.4700, unsup_loss:-243.7349, test_accuracy:0.8833
# Epoch [76/100], time 109.18s, sup_loss:-219.7051, sup_clf_loss:0.3101, unsup_loss:-241.1440, test_accuracy:0.8885
# Epoch [77/100], time 109.19s, sup_loss:-217.6809, sup_clf_loss:0.3093, unsup_loss:-243.1259, test_accuracy:0.8759
# Epoch [78/100], time 111.89s, sup_loss:-219.5086, sup_clf_loss:0.2997, unsup_loss:-242.5086, test_accuracy:0.8871
# Epoch [79/100], time 111.84s, sup_loss:-220.4188, sup_clf_loss:0.3458, unsup_loss:-243.4440, test_accuracy:0.8800
# Epoch [80/100], time 111.74s, sup_loss:-220.1203, sup_clf_loss:0.3132, unsup_loss:-243.1494, test_accuracy:0.8744
# Epoch [81/100], time 111.77s, sup_loss:-218.5521, sup_clf_loss:0.3040, unsup_loss:-240.5554, test_accuracy:0.8633
# Epoch [82/100], time 111.65s, sup_loss:-217.5440, sup_clf_loss:0.4762, unsup_loss:-241.5276, test_accuracy:0.8411
# Epoch [83/100], time 109.44s, sup_loss:-220.9659, sup_clf_loss:0.3142, unsup_loss:-242.3226, test_accuracy:0.8772
# Epoch [84/100], time 110.06s, sup_loss:-220.1472, sup_clf_loss:0.2849, unsup_loss:-242.9073, test_accuracy:0.8953
# Epoch [85/100], time 128.27s, sup_loss:-217.7516, sup_clf_loss:0.2863, unsup_loss:-243.1557, test_accuracy:0.8921
# Epoch [86/100], time 130.83s, sup_loss:-222.7082, sup_clf_loss:0.4893, unsup_loss:-245.3312, test_accuracy:0.8746
# Epoch [87/100], time 125.10s, sup_loss:-220.0332, sup_clf_loss:0.2999, unsup_loss:-244.1812, test_accuracy:0.8885
# Epoch [88/100], time 123.70s, sup_loss:-220.5744, sup_clf_loss:0.2780, unsup_loss:-245.0328, test_accuracy:0.8972
# Epoch [89/100], time 125.99s, sup_loss:-218.8960, sup_clf_loss:0.5224, unsup_loss:-244.3071, test_accuracy:0.8206
# Epoch [90/100], time 112.85s, sup_loss:-222.4586, sup_clf_loss:0.4553, unsup_loss:-244.3870, test_accuracy:0.8785
# Epoch [91/100], time 113.67s, sup_loss:-220.1531, sup_clf_loss:0.3471, unsup_loss:-246.2120, test_accuracy:0.8821
# Epoch [92/100], time 119.13s, sup_loss:-220.8141, sup_clf_loss:0.2883, unsup_loss:-244.8500, test_accuracy:0.8939
# Epoch [93/100], time 115.28s, sup_loss:-220.0346, sup_clf_loss:0.2794, unsup_loss:-244.4063, test_accuracy:0.8897
# Epoch [94/100], time 124.90s, sup_loss:-220.6898, sup_clf_loss:0.3393, unsup_loss:-244.8035, test_accuracy:0.8901
# Epoch [95/100], time 116.23s, sup_loss:-220.3296, sup_clf_loss:0.2822, unsup_loss:-245.5144, test_accuracy:0.8038
# Epoch [96/100], time 119.65s, sup_loss:-220.8300, sup_clf_loss:0.6590, unsup_loss:-246.7631, test_accuracy:0.8754
# Epoch [97/100], time 125.06s, sup_loss:-220.6361, sup_clf_loss:0.3503, unsup_loss:-245.5396, test_accuracy:0.8969
# Epoch [98/100], time 110.52s, sup_loss:-220.5653, sup_clf_loss:0.2720, unsup_loss:-246.6503, test_accuracy:0.8939
# Epoch [99/100], time 115.53s, sup_loss:-221.5734, sup_clf_loss:0.2695, unsup_loss:-245.1397, test_accuracy:0.8992
# Epoch [100/100], time 118.49s, sup_loss:-221.2189, sup_clf_loss:0.2796, unsup_loss:-247.6304, test_accuracy:0.9008

# %%
fig, axes = plt.subplots(4,1, figsize=(15,20))
fig.tight_layout()
axes[0].plot(np.array(sup_loss), label="supervised loss")
axes[0].plot(np.array(unsup_loss), label="unsupervised loss")

axes[1].plot(np.array(clf_loss), label="classification loss")

axes[2].plot(np.array(test_acc), label="accuracy")
axes[2].grid(True)

axes[3].plot(np.array(sup_loss) + np.array(unsup_loss)  + np.array(clf_loss), label=r"J^{alpha}")

plt.show()

# %%
#torch.save(ss_vae, "models_and_losses/SSVAE_CBN_lr-1e-4_100ep.pt")
#torch.save(ss_vae.state_dict(), "models_and_losses/SSVAE_CBN_lr-1e-4_state_dict_100ep.pt")
#torch.save(ss_vae.encoder_y, "models_and_losses/SSVAE_CBN_classifier_lr-1e-4_100ep.pt")
#torch.save(ss_vae.encoder_y.state_dict(), "models_and_losses/SSVAE_CBN_classifier_lr-1e-4_state_dict_100ep.pt")

# %%
for i in range(100,150): # 10 epochs for start
    start = time.time()
    epoch_sup_loss, epoch_unsup_loss = run_inference_for_epoch(data_loaders, losses)

    sup_loss.append(epoch_sup_loss[0]/sup_num)
    clf_loss.append(epoch_sup_loss[1]/sup_num)
    unsup_loss.append(epoch_unsup_loss[0]/unsup_num)

    test_accuracy = get_accuracy(data_loaders["test"], ss_vae.encoder_y)
    test_acc.append(test_accuracy)

    
    print("Epoch [{}/{}], time {:.2f}s, sup_loss:{:.4f}, sup_clf_loss:{:.4f}, unsup_loss:{:.4f}, test_accuracy:{:.4f}"\
          .format(i+1, 150, time.time()-start, sup_loss[-1], clf_loss[-1], unsup_loss[-1], test_accuracy))
# Out:
# Epoch [101/150], time 110.15s, sup_loss:-220.7204, sup_clf_loss:0.5288, unsup_loss:-245.7946, test_accuracy:0.8973
# Epoch [102/150], time 109.95s, sup_loss:-221.7937, sup_clf_loss:0.2699, unsup_loss:-247.8917, test_accuracy:0.8955
# Epoch [103/150], time 112.07s, sup_loss:-223.1669, sup_clf_loss:0.2653, unsup_loss:-247.0171, test_accuracy:0.8975
# Epoch [104/150], time 116.04s, sup_loss:-222.9911, sup_clf_loss:0.2639, unsup_loss:-245.6354, test_accuracy:0.8992
# Epoch [105/150], time 119.98s, sup_loss:-222.7225, sup_clf_loss:0.4212, unsup_loss:-246.4071, test_accuracy:0.8900
# Epoch [106/150], time 111.19s, sup_loss:-223.1916, sup_clf_loss:0.2698, unsup_loss:-246.7125, test_accuracy:0.8945
# Epoch [107/150], time 111.22s, sup_loss:-223.1419, sup_clf_loss:0.3160, unsup_loss:-247.3233, test_accuracy:0.8897
# Epoch [108/150], time 114.42s, sup_loss:-221.3698, sup_clf_loss:0.2596, unsup_loss:-248.7618, test_accuracy:0.8951
# Epoch [109/150], time 118.22s, sup_loss:-225.0509, sup_clf_loss:0.2767, unsup_loss:-247.8478, test_accuracy:0.8991
# Epoch [110/150], time 107.03s, sup_loss:-225.4048, sup_clf_loss:0.5360, unsup_loss:-248.6781, test_accuracy:0.8947
# Epoch [111/150], time 106.11s, sup_loss:-223.4774, sup_clf_loss:0.2646, unsup_loss:-247.4050, test_accuracy:0.8589
# Epoch [112/150], time 105.97s, sup_loss:-223.7099, sup_clf_loss:0.2639, unsup_loss:-246.3060, test_accuracy:0.9016
# Epoch [113/150], time 107.55s, sup_loss:-225.3593, sup_clf_loss:0.2525, unsup_loss:-247.2836, test_accuracy:0.9018
# Epoch [114/150], time 106.58s, sup_loss:-224.6021, sup_clf_loss:0.2553, unsup_loss:-249.5987, test_accuracy:0.8998
# Epoch [115/150], time 107.02s, sup_loss:-222.6449, sup_clf_loss:0.2596, unsup_loss:-246.8129, test_accuracy:0.8977
# Epoch [116/150], time 106.27s, sup_loss:-223.6206, sup_clf_loss:0.2526, unsup_loss:-249.4692, test_accuracy:0.8996
# Epoch [117/150], time 106.36s, sup_loss:-227.1188, sup_clf_loss:0.4435, unsup_loss:-248.1534, test_accuracy:0.8868
# Epoch [118/150], time 106.45s, sup_loss:-224.0846, sup_clf_loss:0.2745, unsup_loss:-247.5833, test_accuracy:0.9025
# Epoch [119/150], time 106.76s, sup_loss:-225.7672, sup_clf_loss:0.2614, unsup_loss:-248.4968, test_accuracy:0.8989
# Epoch [120/150], time 106.42s, sup_loss:-224.7792, sup_clf_loss:0.3757, unsup_loss:-248.3760, test_accuracy:0.8976
# Epoch [121/150], time 107.04s, sup_loss:-225.3460, sup_clf_loss:0.3212, unsup_loss:-248.3257, test_accuracy:0.8891
# Epoch [122/150], time 106.62s, sup_loss:-224.6788, sup_clf_loss:0.2574, unsup_loss:-247.2395, test_accuracy:0.9004
# Epoch [123/150], time 106.55s, sup_loss:-224.7067, sup_clf_loss:0.2606, unsup_loss:-247.1265, test_accuracy:0.9035
# Epoch [124/150], time 107.12s, sup_loss:-227.2042, sup_clf_loss:0.2425, unsup_loss:-247.7657, test_accuracy:0.9043
# Epoch [125/150], time 106.72s, sup_loss:-225.7098, sup_clf_loss:0.2849, unsup_loss:-249.1586, test_accuracy:0.9045
# Epoch [126/150], time 107.59s, sup_loss:-227.4532, sup_clf_loss:0.2436, unsup_loss:-249.0836, test_accuracy:0.9088
# Epoch [127/150], time 104.87s, sup_loss:-224.5578, sup_clf_loss:0.2475, unsup_loss:-248.3295, test_accuracy:0.8958
# Epoch [128/150], time 105.04s, sup_loss:-227.1688, sup_clf_loss:0.2386, unsup_loss:-249.2889, test_accuracy:0.9087
# Epoch [129/150], time 104.88s, sup_loss:-225.9562, sup_clf_loss:0.2374, unsup_loss:-250.1442, test_accuracy:0.9007
# Epoch [130/150], time 104.80s, sup_loss:-230.1121, sup_clf_loss:0.3109, unsup_loss:-251.9180, test_accuracy:0.9016
# Epoch [131/150], time 104.52s, sup_loss:-225.5436, sup_clf_loss:0.2349, unsup_loss:-249.6220, test_accuracy:0.9097
# Epoch [132/150], time 104.61s, sup_loss:-225.0904, sup_clf_loss:0.2359, unsup_loss:-247.5632, test_accuracy:0.9041
# Epoch [133/150], time 104.90s, sup_loss:-226.8075, sup_clf_loss:0.2394, unsup_loss:-250.9789, test_accuracy:0.9063
# Epoch [134/150], time 104.12s, sup_loss:-224.4150, sup_clf_loss:0.2356, unsup_loss:-250.6895, test_accuracy:0.9012
# Epoch [135/150], time 103.14s, sup_loss:-227.1875, sup_clf_loss:0.4799, unsup_loss:-249.7070, test_accuracy:0.8974
# Epoch [136/150], time 103.47s, sup_loss:-226.2219, sup_clf_loss:0.2516, unsup_loss:-249.1011, test_accuracy:0.9097
# Epoch [137/150], time 103.17s, sup_loss:-227.9186, sup_clf_loss:0.2409, unsup_loss:-250.8506, test_accuracy:0.8620
# Epoch [138/150], time 103.55s, sup_loss:-227.3177, sup_clf_loss:0.2384, unsup_loss:-250.7216, test_accuracy:0.9102
# Epoch [139/150], time 103.13s, sup_loss:-225.6251, sup_clf_loss:0.3996, unsup_loss:-252.1797, test_accuracy:0.9044
# Epoch [140/150], time 103.06s, sup_loss:-228.3430, sup_clf_loss:0.2411, unsup_loss:-250.7172, test_accuracy:0.9062
# Epoch [141/150], time 107.74s, sup_loss:-227.3611, sup_clf_loss:0.2304, unsup_loss:-251.9773, test_accuracy:0.9089
# Epoch [142/150], time 111.29s, sup_loss:-228.0199, sup_clf_loss:0.2294, unsup_loss:-252.3619, test_accuracy:0.9096
# Epoch [143/150], time 108.00s, sup_loss:-228.3384, sup_clf_loss:0.2298, unsup_loss:-250.1214, test_accuracy:0.9089
# Epoch [144/150], time 107.06s, sup_loss:-226.7732, sup_clf_loss:0.2668, unsup_loss:-250.5525, test_accuracy:0.6101
# Epoch [145/150], time 107.40s, sup_loss:-228.7699, sup_clf_loss:0.2791, unsup_loss:-251.9013, test_accuracy:0.9111
# Epoch [146/150], time 106.71s, sup_loss:-225.1546, sup_clf_loss:0.2228, unsup_loss:-252.2539, test_accuracy:0.9122
# Epoch [147/150], time 107.15s, sup_loss:-228.4049, sup_clf_loss:0.2278, unsup_loss:-252.0399, test_accuracy:0.9060
# Epoch [148/150], time 107.51s, sup_loss:-229.6544, sup_clf_loss:0.2321, unsup_loss:-252.7734, test_accuracy:0.8914
# Epoch [149/150], time 107.50s, sup_loss:-225.4507, sup_clf_loss:0.2271, unsup_loss:-250.0727, test_accuracy:0.9089
# Epoch [150/150], time 107.88s, sup_loss:-229.9702, sup_clf_loss:0.2225, unsup_loss:-253.1813, test_accuracy:0.8776

# %%
for i in range(150,160): # 10 epochs for start
    start = time.time()
    epoch_sup_loss, epoch_unsup_loss = run_inference_for_epoch(data_loaders, losses)

    sup_loss.append(epoch_sup_loss[0]/sup_num)
    clf_loss.append(epoch_sup_loss[1]/sup_num)
    unsup_loss.append(epoch_unsup_loss[0]/unsup_num)

    test_accuracy = get_accuracy(data_loaders["test"], ss_vae.encoder_y)
    test_acc.append(test_accuracy)

    
    print("Epoch [{}/{}], time {:.2f}s, sup_loss:{:.4f}, sup_clf_loss:{:.4f}, unsup_loss:{:.4f}, test_accuracy:{:.4f}"\
          .format(i+1, 150, time.time()-start, sup_loss[-1], clf_loss[-1], unsup_loss[-1], test_accuracy))
# Out:
# Epoch [151/150], time 109.92s, sup_loss:-229.5282, sup_clf_loss:0.2242, unsup_loss:-253.4866, test_accuracy:0.8948
# Epoch [152/150], time 108.69s, sup_loss:-229.5477, sup_clf_loss:0.2898, unsup_loss:-250.8673, test_accuracy:0.9138
# Epoch [153/150], time 110.01s, sup_loss:-229.2763, sup_clf_loss:0.2226, unsup_loss:-251.3576, test_accuracy:0.9078
# Epoch [154/150], time 113.12s, sup_loss:-229.1439, sup_clf_loss:0.2230, unsup_loss:-250.6940, test_accuracy:0.9104
# Epoch [155/150], time 110.17s, sup_loss:-228.1710, sup_clf_loss:0.2138, unsup_loss:-252.1126, test_accuracy:0.8972
# Epoch [156/150], time 114.20s, sup_loss:-229.9099, sup_clf_loss:0.2227, unsup_loss:-253.2913, test_accuracy:0.9140
# Epoch [157/150], time 107.87s, sup_loss:-227.6420, sup_clf_loss:0.2146, unsup_loss:-252.1043, test_accuracy:0.9121
# Epoch [158/150], time 107.94s, sup_loss:-228.6852, sup_clf_loss:0.2186, unsup_loss:-252.1643, test_accuracy:0.9074
# Epoch [159/150], time 107.03s, sup_loss:-228.7577, sup_clf_loss:0.3647, unsup_loss:-253.3151, test_accuracy:0.8921
# Epoch [160/150], time 107.25s, sup_loss:-227.3685, sup_clf_loss:0.2343, unsup_loss:-252.1453, test_accuracy:0.9131

# %%
fig, axes = plt.subplots(4,1, figsize=(15,20))
fig.tight_layout()
axes[0].plot(np.array(sup_loss), label="supervised loss")
axes[0].plot(np.array(unsup_loss), label="unsupervised loss")

axes[1].plot(np.array(clf_loss), label="classification loss")

axes[2].plot(np.array(test_acc), label="accuracy")
axes[2].grid(True)

axes[3].plot(np.array(sup_loss) + np.array(unsup_loss)  + np.array(clf_loss), label=r"J^{alpha}")

plt.show()

# %%
import pandas as pd

df = pd.DataFrame({"supervised_loss":sup_loss, "unsupervised_loss":unsup_loss, "classification_loss":clf_loss,"test_accuracy":test_acc})
df.head()
# Out:
#    supervised_loss  unsupervised_loss  classification_loss  test_accuracy
# 0         0.976038         -40.044250             1.832728       0.238755
# 1       -99.865471        -127.604578             1.732039       0.436392
# 2      -127.015881        -151.399563             2.771500       0.292678
# 3      -139.886544        -166.119354             1.234275       0.521108
# 4      -143.956220        -167.912830             1.915163       0.419750

# %%
#torch.save(ss_vae, "models_and_losses/SSVAE_CBN_lr-1e-4_160ep.pt")
#torch.save(ss_vae.state_dict(), "models_and_losses/SSVAE_CBN_lr-1e-4_state_dict_160ep.pt")
#torch.save(ss_vae.encoder_y, "models_and_losses/SSVAE_CBN_classifier_lr-1e-4_160ep.pt")
#torch.save(ss_vae.encoder_y.state_dict(), "models_and_losses/SSVAE_CBN_classifier_lr-1e-4_state_dict_160ep.pt")
# Out:
# C:\Users\ghost_000\Miniconda3\envs\Pytorch\lib\site-packages\torch\serialization.py:360: UserWarning: Couldn't retrieve source code for container of type SSVAE. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# C:\Users\ghost_000\Miniconda3\envs\Pytorch\lib\site-packages\torch\serialization.py:360: UserWarning: Couldn't retrieve source code for container of type Encoder. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# C:\Users\ghost_000\Miniconda3\envs\Pytorch\lib\site-packages\torch\serialization.py:360: UserWarning: Couldn't retrieve source code for container of type VariationalLayer. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# C:\Users\ghost_000\Miniconda3\envs\Pytorch\lib\site-packages\torch\serialization.py:360: UserWarning: Couldn't retrieve source code for container of type ConvTransposeDecoderOutput. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
#df.to_csv("models_and_losses/SSVAE_CBN_lr-1e-4_160ep_losses.csv")

# %%
assert 1==0
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-33-788ee363e0a2> in <module>
# ----> 1 assert 1==0
#
# AssertionError:

# %%
ss_vae.encoder_y.eval()
final_test_accuracy = get_accuracy(data_loaders["test"], ss_vae.encoder_y)
ss_vae.encoder_y.train()
# Out:
# Sequential(
#   (0): Reshape()
#   (1): Conv1d(1, 16, kernel_size=(6,), stride=(2,), bias=False)
#   (2): PReLU(num_parameters=1)
#   (3): Conv1d(16, 32, kernel_size=(4,), stride=(2,), bias=False)
#   (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (5): PReLU(num_parameters=1)
#   (6): Conv1d(32, 64, kernel_size=(4,), stride=(2,), bias=False)
#   (7): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): PReLU(num_parameters=1)
#   (9): Flatten()
#   (10): Linear(in_features=1152, out_features=256, bias=True)
#   (11): PReLU(num_parameters=1)
#   (12): Linear(in_features=256, out_features=4, bias=True)
#   (13): Softmax(dim=1)
# )

# %%
final_test_accuracy
# Out:
# 0.9147673467630854

# %%
pred = ss_vae.encoder_y(torch.tensor(X_test).float().cuda())

# %%
pred = np.argmax(pred.cpu().detach().numpy(), axis=1)

# %%
f1_score(y_true=y_test, y_pred=pred,average="macro")
# Out:
# 0.8717763075935387

# %%
cf1 = confusion_matrix(y_true=y_test, y_pred=pred) # x_axis = predicted, y_axis = ground_truth
cf1
# Out:
# array([[3781,  304,   28,  122],
#        [ 419, 9889,   36,  101],
#        [  26,   31,  408,   14],
#        [ 224,   90,   12, 1251]], dtype=int64)

# %% [markdown]
#      array([[3808,  265,   25,  137],
#            [ 414, 9883,   35,  113],
#            [  22,   34,  404,   19],
#            [ 187,  102,   11, 1277]], dtype=int64)
