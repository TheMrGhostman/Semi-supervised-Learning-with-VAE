# %%
import os

import numpy as np
import torch
import torchvision.datasets as dset
import torch.nn as nn
import torchvision.transforms as transforms

import pyro
import pyro.distributions as dist
import pyro.contrib.examples.util  # patches torchvision
from pyro.infer import SVI, Trace_ELBO
from pyro.optim import Adam

import matplotlib.pyplot as plt

# %%
pyro.enable_validation(True)
pyro.distributions.enable_validation(False)
pyro.set_rng_seed(0)
# Enable smoke test - run the notebook cells on CI.
smoke_test = 'CI' in os.environ

# %%
def setup_data_loaders(batch_size=128, use_cuda=False):
    root = './data'
    download = True
    trans = transforms.ToTensor()
    train_set = dset.mnist.MNIST(root=root, train=True, transform=trans,
                           download=download)
    test_set = dset.mnist.MNIST(root=root, train=False, transform=trans)

    kwargs = {'num_workers': 1, 'pin_memory': use_cuda}
    train_loader = torch.utils.data.DataLoader(dataset=train_set,
        batch_size=batch_size, shuffle=True, **kwargs)
    test_loader = torch.utils.data.DataLoader(dataset=test_set,
        batch_size=batch_size, shuffle=False, **kwargs)
    return train_loader, test_loader

# %%
class Encoder(nn.Module):
    def __init__(self, z_dim, hidden_dim):
        super().__init__()
        # setup the three linear transformations used
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=64, kernel_size=(4,4), stride=2)# 28x28 -> 24/2+1x24/2+1
        self.conv2 = nn.Conv2d(in_channels=64, out_channels=32, kernel_size=(3,3),stride=2)# 13x13 -> 10/2+1x10/2+1
        self.fc1 = nn.Linear(6*6*32, hidden_dim)
        self.fc21 = nn.Linear(hidden_dim, z_dim)
        self.fc22 = nn.Linear(hidden_dim, z_dim)
        # setup the non-linearities
        self.softplus = nn.Softplus()
        self.relu = nn.ReLU()

    def forward(self, x):
        # define the forward computation on the image x
        # first shape the mini-batch to have pixels in the rightmost dimension
        x = self.relu(self.conv1(x))
        x = self.relu(self.conv2(x))
        x = x.view(-1, 6*6*32)
        # then compute the hidden units
        hidden = self.softplus(self.fc1(x))
        # then return a mean vector and a (positive) square root covariance
        # each of size batch_size x z_dim
        z_loc = self.fc21(hidden)
        z_scale = self.softplus(self.fc22(hidden))
        return z_loc, z_scale

# %%
class Decoder(nn.Module):
    def __init__(self, z_dim, hidden_dim):
        super().__init__()
        # setup the two linear transformations used
        self.conv2 = nn.ConvTranspose2d(in_channels=64, out_channels=1, kernel_size=(4,4), stride=2)# 28x28 -> 24/2+1x24/2+1
        self.conv1 = nn.ConvTranspose2d(in_channels=32, out_channels=64, kernel_size=(3,3), stride=2)# 13x13 -> 10/2+1x10/2+1
        self.fc1 = nn.Linear(z_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, 32*6*6)
        # setup the non-linearities
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()

    def forward(self, z):
        # define the forward computation on the latent z
        # first compute the hidden units
        hidden = self.relu(self.fc1(z))
        hidden = self.relu(self.fc2(hidden))
        hidden = hidden.view(-1,32,6,6)
        hidden = self.relu(self.conv1(hidden))
        hidden = self.sigmoid(self.conv2(hidden))
        # return the parameter for the output Bernoulli
        # each is of size batch_size x 784
        loc_img = hidden.view(-1,784)
        return loc_img

# %%
class VAE(nn.Module):
    # by default our latent space is 50-dimensional
    # and we use 400 hidden units
    def __init__(self, z_dim=50, hidden_dim=400, use_cuda=False):
        super().__init__()
        # create the encoder and decoder networks
        self.encoder = Encoder(z_dim, hidden_dim)
        self.decoder = Decoder(z_dim, hidden_dim)

        if use_cuda:
            # calling cuda() here will put all the parameters of
            # the encoder and decoder networks into gpu memory
            self.cuda()
        self.use_cuda = use_cuda
        self.z_dim = z_dim

    # define the model p(x|z)p(z)
    def model(self, x):
        # register PyTorch module `decoder` with Pyro
        pyro.module("decoder", self.decoder)
        with pyro.plate("data", x.shape[0]):
            # setup hyperparameters for prior p(z)
            z_loc = x.new_zeros(torch.Size((x.shape[0], self.z_dim)))
            z_scale = x.new_ones(torch.Size((x.shape[0], self.z_dim)))
            # sample from prior (value will be sampled by guide when computing the ELBO)
            z = pyro.sample("latent", dist.Normal(z_loc, z_scale).to_event(1))
            # decode the latent code z
            loc_img = self.decoder.forward(z)
            # score against actual images
            pyro.sample("obs", dist.Bernoulli(loc_img).to_event(1), obs=x.reshape(-1, 784))

    # define the guide (i.e. variational distribution) q(z|x)
    def guide(self, x):
        # register PyTorch module `encoder` with Pyro
        pyro.module("encoder", self.encoder)
        with pyro.plate("data", x.shape[0]):
            # use the encoder to get the parameters used to define q(z|x)
            z_loc, z_scale = self.encoder.forward(x)
            # sample the latent code z
            pyro.sample("latent", dist.Normal(z_loc, z_scale).to_event(1))

    # define a helper function for reconstructing images
    def reconstruct_img(self, x):
        # encode image x
        z_loc, z_scale = self.encoder(x)
        # sample in latent space
        z = dist.Normal(z_loc, z_scale).sample()
        # decode the image (note we don't sample in image space)
        loc_img = self.decoder(z)
        return loc_img

# %%
def train(svi, train_loader, use_cuda=False):
    # initialize loss accumulator
    epoch_loss = 0.
    # do a training epoch over each mini-batch x returned
    # by the data loader
    for x, _ in train_loader:
        # if on GPU put mini-batch into CUDA memory
        if use_cuda:
            x = x.cuda()
        # do ELBO gradient and accumulate loss
        epoch_loss += svi.step(x)

    # return epoch loss
    normalizer_train = len(train_loader.dataset)
    total_epoch_loss_train = epoch_loss / normalizer_train
    return total_epoch_loss_train

# %%
def evaluate(svi, test_loader, use_cuda=False):
    # initialize loss accumulator
    test_loss = 0.
    # compute the loss over the entire test set
    for x, _ in test_loader:
        # if on GPU put mini-batch into CUDA memory
        if use_cuda:
            x = x.cuda()
        # compute ELBO estimate and accumulate loss
        test_loss += svi.evaluate_loss(x)
    normalizer_test = len(test_loader.dataset)
    total_epoch_loss_test = test_loss / normalizer_test
    return total_epoch_loss_test

# %% [markdown]
# # Training

# %%
# Run options
LEARNING_RATE = 1.0e-3
USE_CUDA = True

# Run only for a single iteration for testing
NUM_EPOCHS = 100
TEST_FREQUENCY = 5

# %%
train_loader, test_loader = setup_data_loaders(batch_size=512, use_cuda=USE_CUDA)

# clear param store
pyro.clear_param_store()

# %%
# setup the VAE
vae = VAE(use_cuda=USE_CUDA)

# setup the optimizer
adam_args = {"lr": LEARNING_RATE}
optimizer = Adam(adam_args)

# setup the inference algorithm
svi = SVI(vae.model, vae.guide, optimizer, loss=Trace_ELBO())

# %%
train_elbo = []
test_elbo = []
# training loop
for epoch in range(NUM_EPOCHS):
    total_epoch_loss_train = train(svi, train_loader, use_cuda=USE_CUDA)
    train_elbo.append(-total_epoch_loss_train)
    print("[epoch %03d]  average training loss: %.4f" % (epoch, total_epoch_loss_train))

    if epoch % TEST_FREQUENCY == 0:
        # report test diagnostics
        total_epoch_loss_test = evaluate(svi, test_loader, use_cuda=USE_CUDA)
        test_elbo.append(-total_epoch_loss_test)
        print("[epoch %03d] average test loss: %.4f" % (epoch, total_epoch_loss_test))
# Out:
# [epoch 000]  average training loss: 233.2692
# [epoch 000] average test loss: 183.7789
# [epoch 001]  average training loss: 162.4614
# [epoch 002]  average training loss: 138.0657
# [epoch 003]  average training loss: 124.9767
# [epoch 004]  average training loss: 117.6331
# [epoch 005]  average training loss: 113.3077
# [epoch 005] average test loss: 111.6458
# [epoch 006]  average training loss: 110.6341
# [epoch 007]  average training loss: 108.6444
# [epoch 008]  average training loss: 107.1784
# [epoch 009]  average training loss: 105.8518
# [epoch 010]  average training loss: 104.9143
# [epoch 010] average test loss: 104.2132
# [epoch 011]  average training loss: 104.1332
# [epoch 012]  average training loss: 103.4340
# [epoch 013]  average training loss: 102.8925
# [epoch 014]  average training loss: 102.4303
# [epoch 015]  average training loss: 102.0591
# [epoch 015] average test loss: 102.0178
# [epoch 016]  average training loss: 101.6062
# [epoch 017]  average training loss: 101.3327
# [epoch 018]  average training loss: 101.0230
# [epoch 019]  average training loss: 100.6948
# [epoch 020]  average training loss: 100.4372
# [epoch 020] average test loss: 100.6350
# [epoch 021]  average training loss: 100.2018
# [epoch 022]  average training loss: 99.9876
# [epoch 023]  average training loss: 99.8549
# [epoch 024]  average training loss: 99.5653
# [epoch 025]  average training loss: 99.4183
# [epoch 025] average test loss: 99.8791
# [epoch 026]  average training loss: 99.3040
# [epoch 027]  average training loss: 99.0844
# [epoch 028]  average training loss: 98.9331
# [epoch 029]  average training loss: 98.8331
# [epoch 030]  average training loss: 98.7718
# [epoch 030] average test loss: 99.2565
# [epoch 031]  average training loss: 98.5763
# [epoch 032]  average training loss: 98.3953
# [epoch 033]  average training loss: 98.2806
# [epoch 034]  average training loss: 98.1900
# [epoch 035]  average training loss: 98.1608
# [epoch 035] average test loss: 98.1168
# [epoch 036]  average training loss: 98.0190
# [epoch 037]  average training loss: 97.9313
# [epoch 038]  average training loss: 97.8638
# [epoch 039]  average training loss: 97.6863
# [epoch 040]  average training loss: 97.6627
# [epoch 040] average test loss: 97.6250
# [epoch 041]  average training loss: 97.5161
# [epoch 042]  average training loss: 97.5165
# [epoch 043]  average training loss: 97.3776
# [epoch 044]  average training loss: 97.3352
# [epoch 045]  average training loss: 97.3391
# [epoch 045] average test loss: 97.6489
# [epoch 046]  average training loss: 97.1808
# [epoch 047]  average training loss: 97.1296
# [epoch 048]  average training loss: 97.0974
# [epoch 049]  average training loss: 96.9829
# [epoch 050]  average training loss: 96.9295
# [epoch 050] average test loss: 97.2476
# [epoch 051]  average training loss: 96.8590
# [epoch 052]  average training loss: 96.7670
# [epoch 053]  average training loss: 96.8166
# [epoch 054]  average training loss: 96.6972
# [epoch 055]  average training loss: 96.6575
# [epoch 055] average test loss: 96.8987
# [epoch 056]  average training loss: 96.5666
# [epoch 057]  average training loss: 96.5602
# [epoch 058]  average training loss: 96.4814
# [epoch 059]  average training loss: 96.4714
# [epoch 060]  average training loss: 96.3742
# [epoch 060] average test loss: 96.6513
# [epoch 061]  average training loss: 96.2777
# [epoch 062]  average training loss: 96.2826
# [epoch 063]  average training loss: 96.2453
# [epoch 064]  average training loss: 96.1759
# [epoch 065]  average training loss: 96.1925
# [epoch 065] average test loss: 96.8541
# [epoch 066]  average training loss: 96.1153
# [epoch 067]  average training loss: 96.0716
# [epoch 068]  average training loss: 96.0193
# [epoch 069]  average training loss: 95.9817
# [epoch 070]  average training loss: 95.9160
# [epoch 070] average test loss: 96.2778
# [epoch 071]  average training loss: 95.9059
# [epoch 072]  average training loss: 95.8770
# [epoch 073]  average training loss: 95.8787
# [epoch 074]  average training loss: 95.7766
# [epoch 075]  average training loss: 95.7343
# [epoch 075] average test loss: 96.1553
# [epoch 076]  average training loss: 95.6936
# [epoch 077]  average training loss: 95.6474
# [epoch 078]  average training loss: 95.6690
# [epoch 079]  average training loss: 95.6061
# [epoch 080]  average training loss: 95.5798
# [epoch 080] average test loss: 96.1165
# [epoch 081]  average training loss: 95.4960
# [epoch 082]  average training loss: 95.5095
# [epoch 083]  average training loss: 95.4792
# [epoch 084]  average training loss: 95.4733
# [epoch 085]  average training loss: 95.4331
# [epoch 085] average test loss: 96.1345
# [epoch 086]  average training loss: 95.3880
# [epoch 087]  average training loss: 95.3500
# [epoch 088]  average training loss: 95.3442
# [epoch 089]  average training loss: 95.3139
# [epoch 090]  average training loss: 95.3120
# [epoch 090] average test loss: 95.7293
# [epoch 091]  average training loss: 95.2280
# [epoch 092]  average training loss: 95.2373
# [epoch 093]  average training loss: 95.1838
# [epoch 094]  average training loss: 95.1703
# [epoch 095]  average training loss: 95.1093
# [epoch 095] average test loss: 95.8783
# [epoch 096]  average training loss: 95.0650
# [epoch 097]  average training loss: 95.0887
# [epoch 098]  average training loss: 95.0558
# [epoch 099]  average training loss: 95.0374

# %%
plt.figure(figsize=(15,10))
axe = np.arange(len(train_elbo))
plt.plot(axe, train_elbo)
plt.plot(axe[::5], test_elbo)
plt.show()

# %%
tmp = next(iter(test_loader))[0]

# %%
tmp[:100]
# Out:
# torch.Size([100, 1, 28, 28])

# %%
rec = vae.reconstruct_img(tmp[:100].cuda())

# %%
rec = vae.decoder(torch.randn((100,50)).cuda())

# %%
fig,ax = plt.subplots(10,10, figsize=(20,20))
for i in range(10):
    for j in range(10):
        ax[i][j].imshow(rec[i*10+j].cpu().detach().numpy().reshape(28,28))
        
plt.show()

# %%
plt.figure()
plt.imshow(np.random.randn(7,7))
plt.show()

# %%
#torch.save(vae.state_dict(), "Z:\Tex Diplomka Obrázky\VAE_with_Pyro_MNIST_state_dict.pt")
